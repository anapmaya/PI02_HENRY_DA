# %% [markdown]
# # ETL
# ## Exploración no estadística, y disponibilización de los datos del archivo Homicidios.xlsx

# %%
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")

from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# %% [markdown]
# ### Extracción
# Importo los datos contenidos en el archivo homicidios.xlsx, que trae dos hojas: HECHOS y VICTIMAS. Almaceno en dos dataframes independientes

# %%
df_HH = pd.read_excel('homicidios.xlsx', sheet_name= "HECHOS")
df_HV = pd.read_excel('homicidios.xlsx', sheet_name= "VICTIMAS")

# %% [markdown]
# ### Análisis exploratorio inicial y transformación de datos para dataframe de HECHOS (df_HH)

# %%
df_HH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Altura                 129 non-null    float64
#  12  Cruce                  525 non-null    object
#  13  Dirección Normalizada  688 non-null    object
#  14  COMUNA                 696 non-null    int64
#  15  XY (CABA)              696 non-null    object
#  16  pos x                  696 non-null    object
#  17  pos y                  696 non-null    object
#  18  PARTICIPANTES          696 non-null    object
#  19  VICTIMA                696 non-null    object
#  20  ACUSADO                696 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(14)
# memory usage: 114.3+ KB

# %% [markdown]
# #### Revisión de Datos Nulos

# %%
df_HH.isnull().sum()
# Out:
# ID                         0
# N_VICTIMAS                 0
# FECHA                      0
# AAAA                       0
# MM                         0
# DD                         0
# HORA                       0
# HH                         0
# LUGAR_DEL_HECHO            0
# TIPO_DE_CALLE              0
# Calle                      1
# Altura                   567
# Cruce                    171
# Dirección Normalizada      8
# COMUNA                     0
# XY (CABA)                  0
# pos x                      0
# pos y                      0
# PARTICIPANTES              0
# VICTIMA                    0
# ACUSADO                    0
# dtype: int64

# %% [markdown]
# De esta primera exploración, sumada a una revisión manual al abrir el archivo en excel, se puede apreciar que es un dataset bastante limpio y casi listo para trabajar. Tiene información completa, es decir sin datos nulos, en las columnas ID, N_VICITMAS, FECHA, AAA, MM, DD, HORA, LUGAR DEL HECHO, TIPO DE CALLE, COMUNA, PARTICIPANTES, VICTIMA, ACUSADO.
#
# EN LAS COLUMNAS XY (CABA), pos x, pos y, aparentemente no hay datos nulos, pero al revisar en excel se pueden encontrar varios registros en los cuales no hay realmente información en estos campos sino puntos (.), lo que para efectos prácticos equivale a valores nulos o vacíos.
#
# Otras columnas con algunos datos nulos son las que corresponden al desglose de la dirección: Calle, Altura, Cruce, Dirección Normalizada.
#
# Los nombres que traen las columnas tal vez sugerían ya esa información, pues las columnas que están completas tienen su nombre todo escrito en mayúsculas (Con excepción de XY CABA), y las incompletas están en minúsculas.
#
# Un reto grande con el que me encuentro, al no ser ciudadana Argentina, es entender cómo funcionan las direcciones en la ciudad.

# %% [markdown]
# #### Columnas XY (CABA), pos x, pos y
#
# La geolocalización es importante para los ánalisis que se deben realizar, así que no quiero eliminar los registros en los que estos datos no existen. Intentaré utilizar la información que poseo sobre el lugar del accidente para completar la que hace falta. Para esta tarea utilizaré GeoPy que es una librería de python para acceder a servicios de geocodificación.
#
# Mi objetivo es conseguir los valores de las coordenadas X, Y. El valor de XY(CABA) -geocodificación plana-, podría ser útil a la hora de utilizar mapas pero eso lo decidiré más adelante.

# %%
#Observo los registros que necesito completar:
df_sinXY = df_HH[df_HH['XY (CABA)']=='Point (. .)'][['ID','LUGAR_DEL_HECHO', 'Dirección Normalizada', 'XY (CABA)', 'pos x', 'pos y']]
df_sinXY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 35 to 621
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     14 non-null     object
#  1   LUGAR_DEL_HECHO        14 non-null     object
#  2   Dirección Normalizada  6 non-null      object
#  3   XY (CABA)              14 non-null     object
#  4   pos x                  14 non-null     object
#  5   pos y                  14 non-null     object
# dtypes: object(6)
# memory usage: 784.0+ bytes

# %%
df_sinXY
# Out:
#             ID                                    LUGAR_DEL_HECHO  \
# 35   2016-0049  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI KM....
# 38   2016-0052                         AUTOPISTA LUGONES PK 10000
# 71   2016-0096       AUTOPISTA DELLEPIANE LUIS TTE. GRAL. KM. 2,3
# 106  2016-0136                   AU BUENOS AIRES - LA PLATA KM. 4
# 119  2016-0151                                                 SD
# 139  2016-0174                               AUTOPISTA 25 DE MAYO
# 176  2017-0042                      AV. LEOPOLDO LUGONES PKM 6900
# 180  2017-0050            AU PERITO MORENO Y RAMAL ENLACE AU1/AU6
# 181  2017-0051                                 AU DELLEPIANE 2400
# 256  2017-0140                        AU ARTURO FRONDIZI PKM 3100
# 313  2018-0039                           AUTOPISTA LUGONES KM 4.7
# 546  2020-0026                       LUGONES, LEOPOLDO AV. KM 6,1
# 559  2020-0039                                    MURGUIONDO 2700
# 621  2021-0023                   AU BUENOS AIRES LA PLATA  KM 4,5
#
#                           Dirección Normalizada    XY (CABA)  \
# 35   AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI  Point (. .)
# 38                                          NaN  Point (. .)
# 71         AUTOPISTA DELLEPIANE LUIS TTE. GRAL.  Point (. .)
# 106                                         NaN  Point (. .)
# 119                                         NaN  Point (. .)
# 139                        AUTOPISTA 25 DE MAYO  Point (. .)
# 176                       LUGONES, LEOPOLDO AV.  Point (. .)
# 180                                         NaN  Point (. .)
# 181                                         NaN  Point (. .)
# 256  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI  Point (. .)
# 313                                         NaN  Point (. .)
# 546                                         NaN  Point (. .)
# 559                                  MURGUIONDO  Point (. .)
# 621                                         NaN  Point (. .)
#
#                   pos x               pos y
# 35   -58.37714647568196  -34.63657525428238
# 38                    .                   .
# 71   -58.47433193007387  -34.66684950051973
# 106                   .                   .
# 119                   .                   .
# 139                   .                   .
# 176                   .                   .
# 180                   .                   .
# 181                   .                   .
# 256                   .                   .
# 313                   .                   .
# 546                   .                   .
# 559                   .                   .
# 621                   .                   .

# %% [markdown]
# Son 12 registros que no tienen valores en pos x y pos y. Y 14 que no tienen XY (CABA). Utilizo geolocator para conseguir las coordenadas geográficas a partir del LUGAR_DEL_HECHO

# %%
geolocator = Nominatim(user_agent="myGeocoder", timeout=10)

def do_geocode(address):
     return geolocator.geocode(address)

# %%
df_sinXY['coordenadas'] =df_sinXY['LUGAR_DEL_HECHO'].apply(do_geocode).apply(lambda loc: tuple(loc.point) if loc else None)
df_sinXY
# Out:
#                                        LUGAR_DEL_HECHO  \
# 35   AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI KM....
# 38                          AUTOPISTA LUGONES PK 10000
# 71        AUTOPISTA DELLEPIANE LUIS TTE. GRAL. KM. 2,3
# 106                   AU BUENOS AIRES - LA PLATA KM. 4
# 119                                                 SD
# 139                               AUTOPISTA 25 DE MAYO
# 176                      AV. LEOPOLDO LUGONES PKM 6900
# 180            AU PERITO MORENO Y RAMAL ENLACE AU1/AU6
# 181                                 AU DELLEPIANE 2400
# 256                        AU ARTURO FRONDIZI PKM 3100
# 313                           AUTOPISTA LUGONES KM 4.7
# 546                       LUGONES, LEOPOLDO AV. KM 6,1
# 559                                    MURGUIONDO 2700
# 621                   AU BUENOS AIRES LA PLATA  KM 4,5
#
#                           Dirección Normalizada    XY (CABA)  \
# 35   AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI  Point (. .)
# 38                                          NaN  Point (. .)
# 71         AUTOPISTA DELLEPIANE LUIS TTE. GRAL.  Point (. .)
# 106                                         NaN  Point (. .)
# 119                                         NaN  Point (. .)
# 139                        AUTOPISTA 25 DE MAYO  Point (. .)
# 176                       LUGONES, LEOPOLDO AV.  Point (. .)
# 180                                         NaN  Point (. .)
# 181                                         NaN  Point (. .)
# 256  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI  Point (. .)
# 313                                         NaN  Point (. .)
# 546                                         NaN  Point (. .)
# 559                                  MURGUIONDO  Point (. .)
# 621                                         NaN  Point (. .)
#
#                   pos x               pos y                      coordenadas
# 35   -58.37714647568196  -34.63657525428238                             None
# 38                    .                   .                             None
# 71   -58.47433193007387  -34.66684950051973                             None
# 106                   .                   .                             None
# 119                   .                   .    (14.5844444, 29.4917691, 0.0)
# 139                   .                   .   (-34.6425804, -58.461474, 0.0)
# 176                   .                   .                             None
# 180                   .                   .                             None
# 181                   .                   .  (-31.4271733, -64.2087771, 0.0)
# 256                   .                   .                             None
# 313                   .                   .                             None
# 546                   .                   .                             None
# 559                   .                   .    (-34.66337, -58.4932488, 0.0)
# 621                   .                   .                             None

# %% [markdown]
# Sé que esto es código redundante, pero siendo tan pocos los datos nuevos que debo añadir al dataframe, decido hacerlo de forma manual. Ya conozco cuáles registros lograron obtener sus coordenadas de latitud y longitud, entonces realizo de nuevo el proceso, uno a uno, y reemplazo los datos en sus columnas correspondientes. Los índices de los registros modificados son 559, 181 y 139.

# %%
geolocator = Nominatim(user_agent="myGeocoder", timeout=50)
location = geolocator.geocode("MURGUIONDO, Buenos Aires, Argentina")
df_HH['pos y'][559] = location.latitude
df_HH['pos x'][559] = location.longitude

# %% [markdown]
# Lleno con ceros el resto de los datos que quedan vacíos en XY (CABA), pos x y pos y, para efectos del manejo en dashboard

# %%
df_HH['pos x'] = df_HH['pos x'].replace('.', 0)
df_HH['pos y'] = df_HH['pos y'].replace('.', 0)
df_HH['XY (CABA)'] = df_HH['XY (CABA)'].replace('Point (. .)', 0)

# %% [markdown]
# #### Columnas 'Altura' y 'Cruce'
#
# Son las dos columnas que presentan más valores nulos, y puedo ver que son complementarias en la información que contienen.
# Indican si el accidente ocurrió en una esquina (cruce de vías), o en la mitad de una cuadra. Es una información importante que se puede resumir en una sola columna, en la que consignaré si el accidente ocurrió o no ocurrió en un cruce. Esto implicará conservar la columna 'Cruce' cambiando sus valores a True/False y eliminar la columna 'Altura'.
# De esta manera también la Columna 'Cruce' quedaría completa, sin valores nulos.

# %%
df_HH = df_HH.drop('Altura', axis=1)

# %%
df_HH['Cruce'] = df_HH['Cruce'].notna()
df_HH.head(15)
# Out:
#            ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 0   2016-0001           1 2016-01-01  2016   1   1  04:00:00   4
# 1   2016-0002           1 2016-01-02  2016   1   2  01:15:00   1
# 2   2016-0003           1 2016-01-03  2016   1   3  07:00:00   7
# 3   2016-0004           1 2016-01-10  2016   1  10  00:00:00   0
# 4   2016-0005           1 2016-01-21  2016   1  21  05:20:00   5
# 5   2016-0008           1 2016-01-24  2016   1  24  18:30:00  18
# 6   2016-0009           1 2016-01-24  2016   1  24  19:10:00  19
# 7   2016-0010           1 2016-01-29  2016   1  29  15:20:00  15
# 8   2016-0012           1 2016-02-08  2016   2   8  01:20:00   1
# 9   2016-0013           1 2016-02-10  2016   2  10  11:30:00  11
# 10  2016-0015           1 2016-02-14  2016   2  14  05:14:00   5
# 11  2016-0016           1 2016-02-14  2016   2  14  22:00:00  22
# 12  2016-0017           1 2016-02-15  2016   2  15  16:54:00  16
# 13  2016-0019           1 2016-02-17  2016   2  17  09:30:00   9
# 14  2016-0020           1 2016-02-17  2016   2  17  16:00:00  16
#
#                                       LUGAR_DEL_HECHO TIPO_DE_CALLE  \
# 0           AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA
# 1                   AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ
# 2                                  AV ENTRE RIOS 2034       AVENIDA
# 3               AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA
# 4           AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA
# 5                      AV 27 DE FEBRERO Y AV ESCALADA       AVENIDA
# 6                        NOGOYA Y JOAQUIN V. GONZALES         CALLE
# 7                 AV GENERAL PAZ Y AV DE LOS CORRALES      GRAL PAZ
# 8                  AV BELGRANO Y BERNARDO DE IRIGOYEN       AVENIDA
# 9                                  AV ENTRE RIOS 1366       AVENIDA
# 10                         AV SCALABRINI ORTIZ Y VERA       AVENIDA
# 11  AV REGIMIENTO DE PATRICIOS Y QUINQUELA MARTIN ...       AVENIDA
# 12                   MARIANO ACOSTA Y ANA MARIA JANER       AVENIDA
# 13  LISANDRO DE LA TORRE Y SEVERO GARCIA GRANDE DE...         CALLE
# 14                                       SUIPACHA 156         CALLE
#
#                           Calle  Cruce  \
# 0              PIEDRA BUENA AV.   True
# 1                PAZ, GRAL. AV.   True
# 2                ENTRE RIOS AV.  False
# 3                LARRAZABAL AV.   True
# 4                  SAN JUAN AV.   True
# 5             27 DE FEBRERO AV.   True
# 6                        NOGOYA   True
# 7                PAZ, GRAL. AV.   True
# 8                  BELGRANO AV.   True
# 9                ENTRE RIOS AV.  False
# 10   SCALABRINI ORTIZ, RAUL AV.   True
# 11  REGIMIENTO DE PATRICIOS AV.   True
# 12              ACOSTA, MARIANO   True
# 13        DE LA TORRE, LISANDRO   True
# 14                     SUIPACHA  False
#
#                                 Dirección Normalizada  COMUNA  \
# 0   PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...       8
# 1                PAZ, GRAL. AV. y DE LOS CORRALES AV.       9
# 2                                 ENTRE RIOS AV. 2034       1
# 3           LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.       8
# 4             SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.       1
# 5                    27 DE FEBRERO AV. y ESCALADA AV.       8
# 6                       NOGOYA y GONZALEZ, JOAQUIN V.      11
# 7                PAZ, GRAL. AV. y DE LOS CORRALES AV.       9
# 8                BELGRANO AV. e IRIGOYEN, BERNARDO DE       1
# 9                                 ENTRE RIOS AV. 1366       1
# 10                  SCALABRINI ORTIZ, RAUL AV. y VERA      15
# 11  REGIMIENTO DE PATRICIOS AV. y QUINQUELA MARTIN...       4
# 12                 ACOSTA, MARIANO y JANER, ANA MARIA       8
# 13  DE LA TORRE, LISANDRO y GARCIA GRANDE DE ZEQUE...       9
# 14                                       SUIPACHA 156       1
#
#                                   XY (CABA)         pos x         pos y  \
# 0     Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1     Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2    Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3     Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4   Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# 5    Point (101721.59002217 93844.25656649)  -58.44451316  -34.68475866
# 6    Point (96545.87592078 102330.67262199)  -58.50095869  -34.60825440
# 7     Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 8   Point (107595.35084333 101797.50052813)  -58.38048577  -34.61303893
# 9   Point (106616.41069662 100496.44662323)  -58.39114932  -34.62477387
# 10  Point (102357.43746828 103343.52002839)  -58.43760020  -34.59912758
# 11   Point (108661.59115206 98481.75445555)  -58.36882665  -34.64291993
# 12   Point (101228.61094416 96623.72136186)  -58.44989671  -34.65970435
# 13    Point (95727.37083199 97179.35560349)  -58.50990884  -34.65468721
# 14  Point (107684.31807562 102519.17333314)  -58.37952223  -34.60653282
#
#        PARTICIPANTES VICTIMA      ACUSADO
# 0          MOTO-AUTO    MOTO         AUTO
# 1     AUTO-PASAJEROS    AUTO    PASAJEROS
# 2          MOTO-AUTO    MOTO         AUTO
# 3            MOTO-SD    MOTO           SD
# 4     MOTO-PASAJEROS    MOTO    PASAJEROS
# 5   MOTO-OBJETO FIJO    MOTO  OBJETO FIJO
# 6          MOTO-AUTO    MOTO         AUTO
# 7          MOTO-AUTO    MOTO         AUTO
# 8        MOTO-CARGAS    MOTO       CARGAS
# 9        PEATON-AUTO  PEATON         AUTO
# 10       PEATON-AUTO  PEATON         AUTO
# 11         MOTO-AUTO    MOTO         AUTO
# 12       PEATON-MOTO  PEATON         MOTO
# 13  PEATON-PASAJEROS  PEATON    PASAJEROS
# 14       PEATON-AUTO  PEATON         AUTO

# %% [markdown]
# #### Columna ID y revisión de duplicados
#
# No necesita ningún cambio, únicamente validación del tipo de dato que debe ser string.
# Uso esta columna para verificar si hay duplicados. La revisión me muestra que no los hay.

# %%
df_HH['ID'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Columna N_VICTIMAS
# Esta columna contiene valores de tipo entero y no tiene valores nulos. Está lista para ser utilizada.

# %% [markdown]
# #### Columnas FECHA, AAAA, MM, DD, HORA Y HH
#
# Estas columnas contienen información que puede ser redundante, pero no me estorba, no tienen valores nulos que puedan entorpecer las consultas y por lo tanto decido conservarlas como están. Sólo falta verificar tipos de datos.

# %%
#Detecto que hay al menos un registro con SD en la columna HORA. Reviso cuál o cuáles son
df_HH[df_HH['HORA']=='SD'][['ID','FECHA','HORA', 'HH', ]]
# Out:
#             ID      FECHA HORA  HH
# 518  2019-0103 2019-12-18   SD  SD

# %%
#Cambio el valor SD por 0 para poder convertir luego los tipos de datos de estas columnas
df_HH['HORA'][518]=0
df_HH['HH'][518]=0

# %% [markdown]
# #### Columnas LUGAR_DEL_HECHO y Direccion Normalizada
# Ambas columnas almacenan la misma información, sólo cambia el formato. En 'Dirección Normalizada' Hay algunos valores nulos.

# %%
df_HH[df_HH['Dirección Normalizada'].isnull()][['Dirección Normalizada', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE']]
# Out:
#     Dirección Normalizada                          LUGAR_DEL_HECHO  \
# 38                    NaN               AUTOPISTA LUGONES PK 10000
# 106                   NaN         AU BUENOS AIRES - LA PLATA KM. 4
# 119                   NaN                                       SD
# 180                   NaN  AU PERITO MORENO Y RAMAL ENLACE AU1/AU6
# 181                   NaN                       AU DELLEPIANE 2400
# 313                   NaN                 AUTOPISTA LUGONES KM 4.7
# 546                   NaN             LUGONES, LEOPOLDO AV. KM 6,1
# 621                   NaN         AU BUENOS AIRES LA PLATA  KM 4,5
#
#     TIPO_DE_CALLE
# 38      AUTOPISTA
# 106     AUTOPISTA
# 119         CALLE
# 180     AUTOPISTA
# 181     AUTOPISTA
# 313     AUTOPISTA
# 546     AUTOPISTA
# 621     AUTOPISTA

# %% [markdown]
# Son pocos datos pero no tengo información para construir esa dirección con el formato requerido, así que le asigno el valor SD para conservar estos registros

# %%
# Se reemplazan los valores nulos con SD
df_HH['Dirección Normalizada'].fillna("SD", inplace=True)
# Se verifican los datos imputados
df_HH[df_HH['Dirección Normalizada']== 'SD'][['Dirección Normalizada', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE']]
# Out:
#     Dirección Normalizada                          LUGAR_DEL_HECHO  \
# 38                     SD               AUTOPISTA LUGONES PK 10000
# 106                    SD         AU BUENOS AIRES - LA PLATA KM. 4
# 119                    SD                                       SD
# 180                    SD  AU PERITO MORENO Y RAMAL ENLACE AU1/AU6
# 181                    SD                       AU DELLEPIANE 2400
# 313                    SD                 AUTOPISTA LUGONES KM 4.7
# 546                    SD             LUGONES, LEOPOLDO AV. KM 6,1
# 621                    SD         AU BUENOS AIRES LA PLATA  KM 4,5
#
#     TIPO_DE_CALLE
# 38      AUTOPISTA
# 106     AUTOPISTA
# 119         CALLE
# 180     AUTOPISTA
# 181     AUTOPISTA
# 313     AUTOPISTA
# 546     AUTOPISTA
# 621     AUTOPISTA

# %% [markdown]
# #### Columna Calle
# Esta columna tiene un sólo valor nulo. Reviso si puedo corregirlo manualmente con la información de los otros campos

# %%
df_HH[df_HH['Calle'].isna()]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 119  2016-0151           1 2016-11-18  2016  11  18  20:35:00  20
#
#     LUGAR_DEL_HECHO TIPO_DE_CALLE Calle  Cruce Dirección Normalizada  COMUNA  \
# 119              SD         CALLE   NaN  False                    SD       0
#
#     XY (CABA) pos x pos y PARTICIPANTES VICTIMA ACUSADO
# 119         0     0     0     PEATON-SD  PEATON      SD

# %% [markdown]
# Es un campo que contiene muy poca información. Nada sobre el lugar de accidente ni sobre el acusado. Considero que todos los registros suman en las estadísticas de temas tan delicados como este, así que decido conservar el registro, colocando SD en los campos que está vacíos.

# %%
df_HH['Calle'][df_HH['ID']=='2016-0151'] = 'SD'

# %% [markdown]
# Hago un nuevo conteo de valores nulos para verificar que no haya quedado ninguno

# %%
df_HH.isnull().sum()
# Out:
# ID                       0
# N_VICTIMAS               0
# FECHA                    0
# AAAA                     0
# MM                       0
# DD                       0
# HORA                     0
# HH                       0
# LUGAR_DEL_HECHO          0
# TIPO_DE_CALLE            0
# Calle                    0
# Cruce                    0
# Dirección Normalizada    0
# COMUNA                   0
# XY (CABA)                0
# pos x                    0
# pos y                    0
# PARTICIPANTES            0
# VICTIMA                  0
# ACUSADO                  0
# dtype: int64

# %% [markdown]
# #### Columnas TIPO_DE_CALLE, COMUNA, PARTICIPANTES
#
# Estas columnas no tienen valores nulos. Están listas para ser utilizadas.

# %% [markdown]
# #### Columnas VICTIMA y ACUSADO
# Reviso si las categorías presentes en estas columnas corresponden a las informadas en el Diccionario de Datos

# %%
df_HH['ACUSADO'].unique()
# Out:
# array(['AUTO', 'PASAJEROS', 'SD', 'OBJETO FIJO', 'CARGAS', 'MOTO',
#        'MULTIPLE', 'OTRO', 'BICICLETA', 'TREN'], dtype=object)

# %% [markdown]
# Encuentro un valor que no corresponde al los del diccionario, 'MULTIPLE', voy a revisar los registros que lo contienen.

# %%
df_HH[df_HH['ACUSADO'].isin(['MULTIPLE'])]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 31   2016-0044           1 2016-03-31  2016   3  31  19:40:00  19
# 143  2016-0178           1 2016-12-30  2016  12  30  16:18:00  16
# 146  2017-0007           1 2017-01-11  2017   1  11  17:00:00  17
# 153  2017-0014           1 2017-01-28  2017   1  28  08:27:34   8
# 174  2017-0040           1 2017-04-03  2017   4   3  09:40:00   9
# 225  2017-0101           1 2017-08-23  2017   8  23  10:00:00  10
# 277  2018-0003           1 2018-01-05  2018   1   5  10:12:00  10
# 278  2018-0004           1 2018-01-09  2018   1   9  09:40:00   9
# 355  2018-0081           1 2018-07-29  2018   7  29  06:30:00   6
# 375  2018-0101           1 2018-09-21  2018   9  21  00:15:00   0
# 425  2019-0008           1 2019-01-30  2019   1  30  22:45:00  22
# 444  2019-0027           1 2019-03-28  2019   3  28  11:11:00  11
# 458  2019-0041           1 2019-05-11  2019   5  11  20:30:00  20
# 513  2019-0097           1 2019-11-25  2019  11  25  08:50:00   8
# 550  2020-0030           1 2020-06-16  2020   6  16  15:00:00  15
# 643  2021-0045           1 2021-05-26  2021   5  26  17:24:00  17
# 672  2021-0074           1 2021-09-20  2021   9  20  15:00:00  15
#
#                                       LUGAR_DEL_HECHO TIPO_DE_CALLE  \
# 31                   AV JOSE MARIA MORENO Y BALBASTRO       AVENIDA
# 143     REPUBLICA BOLIVARIANA DE VENEZUELA Y SAAVEDRA         CALLE
# 146                                     LIMA Y MEXICO         CALLE
# 153                                AV. DONADO Y ARIAS       AVENIDA
# 174  CAMINO CIUDAD UNUVERSITARIA Y AV. TTE. GUIRALDES       AVENIDA
# 225                         AV. FCO. LACROZE Y ZAPATA       AVENIDA
# 277            Pueyrredon, Honorio, Dr. Av. y Galicia       AVENIDA
# 278                   Del Libertador Av. y Manzanares       AVENIDA
# 355               Castañares Av. y Rivera Indarte Av.       AVENIDA
# 375                          Paz, Gral. Av. y Zapiola      GRAL PAZ
# 425                              PAZ, GRAL. AV. 16080      GRAL PAZ
# 444                          SANTA FE AV. Y AZCUENAGA       AVENIDA
# 458            ALBERDI, JUAN BAUTISTA AV. Y ANDALGALA       AVENIDA
# 513                    AUTOPISTA PERITO MORENO KM 5,6     AUTOPISTA
# 550                               SAN MARTIN AV. 1550       AVENIDA
# 643                          AU FRONDIZI Y SUAREZ AV.     AUTOPISTA
# 672         PAZ, GRAL. AV. Y BALBIN, RICARDO, DR. AV.      GRAL PAZ
#
#                                           Calle  Cruce  \
# 31                       MORENO, JOSE MARIA AV.   True
# 143          REPUBLICA BOLIVARIANA DE VENEZUELA   True
# 146                                        LIMA   True
# 153                                      DONADO   True
# 174                             GUIRALDES, INT.  False
# 225                       LACROZE, FEDERICO AV.   True
# 277                PUEYRREDON, HONORIO, DR. AV.   True
# 278                          DEL LIBERTADOR AV.   True
# 355                              CASTANARES AV.   True
# 375                              PAZ, GRAL. AV.   True
# 425                              PAZ, GRAL. AV.  False
# 444                                SANTA FE AV.   True
# 458                  ALBERDI, JUAN BAUTISTA AV.   True
# 513                     AUTOPISTA PERITO MORENO  False
# 550                              SAN MARTIN AV.  False
# 643  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI  False
# 672                              PAZ, GRAL. AV.   True
#
#                                  Dirección Normalizada  COMUNA  \
# 31                  MORENO, JOSE MARIA AV. y BALBASTRO       7
# 143      REPUBLICA BOLIVARIANA DE VENEZUELA y SAAVEDRA       3
# 146                                      LIMA y MEXICO       1
# 153                                     DONADO y ARIAS      12
# 174                               GUIRALDES, INT. 2699      13
# 225                     LACROZE, FEDERICO AV. y ZAPATA      13
# 277             PUEYRREDON, HONORIO, DR. AV. y GALICIA      15
# 278                    DEL LIBERTADOR AV. y MANZANARES      13
# 355               CASTAÃ‘ARES AV. y RIVERA INDARTE AV.       7
# 375                           PAZ, GRAL. AV. y ZAPIOLA      12
# 425                               PAZ, GRAL. AV. 16080       8
# 444                           SANTA FE AV. y AZCUENAGA       2
# 458             ALBERDI, JUAN BAUTISTA AV. y ANDALGALA       9
# 513                    AUTOPISTA PERITO MORENO KM. 5.6       9
# 550                                SAN MARTIN AV. 1550       6
# 643  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI y S...       4
# 672          PAZ, GRAL. AV. y BALBIN, RICARDO, DR. AV.      12
#
#                                    XY (CABA)         pos x         pos y  \
# 31    Point (102857.73817324 99148.76714504)  -58.43213235  -34.63693953
# 143  Point (105541.07964363 101532.48653010)  -58.40288226  -34.61544091
# 146  Point (107491.43483173 101547.26343171)  -58.38161660  -34.61529543
# 153   Point (97378.59173196 108741.41437861)  -58.49185972  -34.55046754
# 174  Point (102290.82648731 109281.08885461)  -58.43834197  -34.54560369
# 225  Point (101644.77699748 106480.78805418)  -58.44537508  -34.57084818
# 277  Point (101348.13972450 102808.02053976)  -58.44860217  -34.60395657
# 278  Point (100183.96103971 109533.84269558)  -58.46129513  -34.54332766
# 355   Point (101453.89687005 98180.39027169)  -58.44744156  -34.64567171
# 375   Point (98376.44189669 109821.71138325)  -58.48098594  -34.54073130
# 425    Point (98650.97430792 93088.91481914)  -58.47802293  -34.69156793
# 444  Point (105815.73438780 103786.90549585)  -58.39990285  -34.59511714
# 458    Point (95590.61347415 96760.29404728)  -58.51140289  -34.65846419
# 513    Point (98724.36593359 97905.39654686)  -58.47721439  -34.64815069
# 550  Point (101074.10089886 102529.69706887)  -58.45158942  -34.60646580
# 643   Point (107903.91828587 98767.43091425)  -58.37709334  -34.64035082
# 672   Point (96563.66494817 108815.73881056)  -58.50073810  -34.54979510
#
#     PARTICIPANTES    VICTIMA   ACUSADO
# 31       MULTIPLE       MOTO  MULTIPLE
# 143      MULTIPLE     PEATON  MULTIPLE
# 146      MULTIPLE     PEATON  MULTIPLE
# 153      MULTIPLE       MOTO  MULTIPLE
# 174      MULTIPLE       AUTO  MULTIPLE
# 225      MULTIPLE     PEATON  MULTIPLE
# 277      MULTIPLE     PEATON  MULTIPLE
# 278      MULTIPLE       MOTO  MULTIPLE
# 355      MULTIPLE     PEATON  MULTIPLE
# 375      MULTIPLE       AUTO  MULTIPLE
# 425      MULTIPLE       MOTO  MULTIPLE
# 444      MULTIPLE  BICICLETA  MULTIPLE
# 458      MULTIPLE       AUTO  MULTIPLE
# 513      MULTIPLE       MOTO  MULTIPLE
# 550      MULTIPLE       MOTO  MULTIPLE
# 643      MULTIPLE       MOTO  MULTIPLE
# 672      MULTIPLE       MOTO  MULTIPLE

# %% [markdown]
# Veo que en todos estos accidentes los participantes fueron múltiples y hubo una sola víctima fatal. Por ahora dejo esto como está, sin realizar ninguna modificación.

# %%
df_HH['VICTIMA'].unique()
# Out:
# array(['MOTO', 'AUTO', 'PEATON', 'SD', 'CARGAS', 'BICICLETA', 'PASAJEROS',
#        'MOVIL', 'OBJETO FIJO', 'PEATON_MOTO'], dtype=object)

# %% [markdown]
# Encuentro dos valores que no corresponden, OBJETO FIJO y PEATON_MOTO, entonces voy a revisar los registros que los contienen

# %%
df_HH[df_HH['VICTIMA'].isin(['OBJETO FIJO', 'PEATON_MOTO'])]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 230  2017-0108           2 2017-09-02  2017   9   2  04:53:08  4
# 583  2020-0063           2 2020-12-05  2020  12   5  07:10:00  7
#
#               LUGAR_DEL_HECHO TIPO_DE_CALLE           Calle  Cruce  \
# 230   AV. GRAL. PAZ Y MACHAIN      GRAL PAZ  PAZ, GRAL. AV.   True
# 583  NUEVA YORK Y ALTA GRACIA         CALLE      NUEVA YORK   True
#
#         Dirección Normalizada  COMUNA                               XY (CABA)  \
# 230  PAZ, GRAL. AV. y MACHAIN      12  Point (97098.48468623 109019.96106626)
# 583  NUEVA YORK y ALTA GRACIA      11  Point (94080.62190808 102083.62453795)
#
#             pos x         pos y     PARTICIPANTES      VICTIMA ACUSADO
# 230  -58.49491054  -34.54795581  AUTO-OBJETO FIJO  OBJETO FIJO    AUTO
# 583  -58.52783814  -34.61047001  PEATON_MOTO-MOTO  PEATON_MOTO    MOTO

# %% [markdown]
# La información es confusa, pero revisando la hoja de Vícitimas para estos dos casos, se puede ver que en ambos accidentes hubo dos víctimas fatales.
# En el primer caso no tiene mucho sentido que la víctima haya sido un OBJETO FIJO, es cierto que el accidente fue una colisión contra un objeto fijo pero las víctimas fueron PASAJERO_ACOMPAÑANTE.
# En el segundo caso, las vícitmas fatales fueron un PEATON y un PASAJERO_ACOMPAÑANTE.
#
# Voy a revisar otros casos que hayan tenido 2 víctimas, para ver cómo están registrados en esta columna.

# %%
df_HH[df_HH['N_VICTIMAS']==2]
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 29   2016-0041           2 2016-03-29  2016   3  29  11:00:00  11
# 97   2016-0126           2 2016-09-18  2016   9  18  22:45:00  22
# 161  2017-0026           2 2017-02-26  2017   2  26  05:15:00   5
# 171  2017-0036           2 2017-03-29  2017   3  29  18:00:00  18
# 180  2017-0050           2 2017-04-28  2017   4  28  11:08:08  11
# 230  2017-0108           2 2017-09-02  2017   9   2  04:53:08   4
# 234  2017-0112           2 2017-09-10  2017   9  10  09:32:17   9
# 244  2017-0126           2 2017-10-14  2017  10  14  06:15:00   6
# 267  2017-0153           2 2017-12-11  2017  12  11  02:00:00   2
# 289  2018-0015           2 2018-02-06  2018   2   6  01:00:00   1
# 300  2018-0026           2 2018-03-09  2018   3   9  04:45:00   4
# 312  2018-0038           2 2018-04-20  2018   4  20  17:10:00  17
# 359  2018-0085           2 2018-08-03  2018   8   3  18:16:00  18
# 372  2018-0098           2 2018-09-09  2018   9   9  05:00:00   5
# 402  2018-0128           2 2018-11-25  2018  11  25  04:30:00   4
# 427  2019-0010           2 2019-02-02  2019   2   2  07:50:00   7
# 558  2020-0038           2 2020-08-30  2020   8  30  04:00:00   4
# 583  2020-0063           2 2020-12-05  2020  12   5  07:10:00   7
# 596  2020-0077           2 2020-12-25  2020  12  25  06:40:00   6
#
#                                     LUGAR_DEL_HECHO TIPO_DE_CALLE  \
# 29                   AV DIRECTORIO Y RIVERA INDARTE       AVENIDA
# 97                             IRIGOYEN Y TINOGASTA         CALLE
# 161                    AV. PERITO MORENO Y FOURNIER       AVENIDA
# 171             CURUPAYTI Y COLECTORA AV. GRAL. PAZ      GRAL PAZ
# 180         AU PERITO MORENO Y RAMAL ENLACE AU1/AU6     AUTOPISTA
# 230                         AV. GRAL. PAZ Y MACHAIN      GRAL PAZ
# 234                      AU 25 DE MAYO Y AV. VARELA     AUTOPISTA
# 244                   AV. RIESTRA Y CAÑADA DE GOMEZ       AVENIDA
# 267                          ROSARIO Y AV. LA PLATA       AVENIDA
# 289                              Australia Av. 2800       AVENIDA
# 300  Rabanal, Francisco, Intendente Av. y Saenz Av.       AVENIDA
# 312                              AV. RIVADAVIA 1571       AVENIDA
# 359             Entre Rios Av. y Garay, Juan De Av.       AVENIDA
# 372       Av. Gral. Paz e/ Ferre y Beron de Astrada      GRAL PAZ
# 402                            Paz, Gral. Av. 11200      GRAL PAZ
# 427                         DEL LIBERTADOR AV. 4100       AVENIDA
# 558         LAS HERAS GENERAL AV. Y DIAZ, CNEL. AV.       AVENIDA
# 583                        NUEVA YORK Y ALTA GRACIA         CALLE
# 596                   SAN MARTIN AV. Y PUNTA ARENAS       AVENIDA
#
#                                   Calle  Cruce  \
# 29                       DIRECTORIO AV.   True
# 97                             IRIGOYEN   True
# 161                  MORENO, PERITO AV.   True
# 171                      PAZ, GRAL. AV.   True
# 180             AUTOPISTA PERITO MORENO  False
# 230                      PAZ, GRAL. AV.   True
# 234                AUTOPISTA 25 DE MAYO  False
# 244                         RIESTRA AV.   True
# 267                             ROSARIO   True
# 289                       AUSTRALIA AV.  False
# 300  RABANAL, FRANCISCO, INTENDENTE AV.   True
# 312                       RIVADAVIA AV.  False
# 359                      ENTRE RIOS AV.   True
# 372                      PAZ, GRAL. AV.   True
# 402                      PAZ, GRAL. AV.  False
# 427                  DEL LIBERTADOR AV.  False
# 558               LAS HERAS GENERAL AV.   True
# 583                          NUEVA YORK   True
# 596                      SAN MARTIN AV.   True
#
#                               Dirección Normalizada  COMUNA  \
# 29              DIRECTORIO AV. y RIVERA INDARTE AV.       7
# 97                             IRIGOYEN y TINOGASTA      10
# 161                   MORENO, PERITO AV. y FOURNIER       4
# 171                        PAZ, GRAL. AV. y CAMPANA      12
# 180                                              SD       9
# 230                        PAZ, GRAL. AV. y MACHAIN      12
# 234               AUTOPISTA 25 DE MAYO y VARELA AV.       7
# 244                  RIESTRA AV. y CAÃ‘ADA DE GOMEZ       8
# 267                          ROSARIO y LA PLATA AV.       6
# 289                              AUSTRALIA AV. 2800       4
# 300  RABANAL, FRANCISCO, INTENDENTE AV. y SAENZ AV.       4
# 312                              RIVADAVIA AV. 1571       1
# 359             ENTRE RIOS AV. y GARAY, JUAN DE AV.       3
# 372               PAZ, GRAL. AV. y BERON DE ASTRADA       8
# 402                            PAZ, GRAL. AV. 11200       9
# 427                         DEL LIBERTADOR AV. 4100      14
# 558         LAS HERAS GENERAL AV. y DIAZ, CNEL. AV.      14
# 583                        NUEVA YORK y ALTA GRACIA      11
# 596                   SAN MARTIN AV. y PUNTA ARENAS      15
#
#                                    XY (CABA)         pos x         pos y  \
# 29    Point (100232.38564985 99530.25843190)  -58.46076550  -34.63350444
# 97    Point (94275.54271123 100886.87954649)  -58.52572109  -34.62125906
# 161   Point (104113.67806500 97722.68219304)  -58.41842777  -34.64979057
# 171   Point (95300.18060161 105287.23850698)  -58.51452347  -34.58159762
# 180                                        0             0             0
# 230   Point (97098.48468623 109019.96106626)  -58.49491054  -34.54795581
# 234   Point (100479.14412395 98812.52258620)  -58.45807401  -34.63997430
# 244    Point (98466.20276785 94207.42419155)  -58.48003734  -34.68148508
# 267  Point (103186.65733155 101217.09689755)  -58.42855267  -34.61829385
# 289   Point (107053.47849253 98047.93724144)  -58.38636298  -34.64684275
# 300   Point (104283.01090451 97171.08656182)  -58.41657793  -34.65476216
# 312  Point (106840.31999667 102262.72809661)  -58.38872177  -34.60885045
# 359  Point (106612.54991859 100244.75667446)  -58.39118948  -34.62704273
# 372    Point (99203.46279192 92552.75548716)  -58.47199387  -34.69640164
# 402    Point (94027.41355272 98150.01779732)  -58.52844623  -34.64592873
# 427  Point (103359.87920798 106617.17056502)  -58.42668489  -34.56961468
# 558  Point (105241.05562982 105080.52102657)  -58.40617526  -34.58345898
# 583   Point (94080.62190808 102083.62453795)  -58.52783814  -34.61047001
# 596   Point (99182.71320106 103123.43585183)  -58.47220945  -34.60111373
#
#         PARTICIPANTES      VICTIMA      ACUSADO
# 29        MOTO-CARGAS         MOTO       CARGAS
# 97        AUTO-CARGAS         AUTO       CARGAS
# 161  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 171    MOTO-PASAJEROS         MOTO    PASAJEROS
# 180       MOTO-CARGAS         MOTO       CARGAS
# 230  AUTO-OBJETO FIJO  OBJETO FIJO         AUTO
# 234  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 244  AUTO-OBJETO FIJO         AUTO  OBJETO FIJO
# 267    MOTO-PASAJEROS         MOTO    PASAJEROS
# 289    MOTO-PASAJEROS         MOTO    PASAJEROS
# 300      MOVIL-CARGAS        MOVIL       CARGAS
# 312       PEATON-AUTO       PEATON         AUTO
# 359    MOTO-PASAJEROS         MOTO    PASAJEROS
# 372         AUTO-AUTO         AUTO         AUTO
# 402    AUTO-PASAJEROS         AUTO    PASAJEROS
# 427       PEATON-AUTO       PEATON         AUTO
# 558         AUTO-AUTO         AUTO         AUTO
# 583  PEATON_MOTO-MOTO  PEATON_MOTO         MOTO
# 596         MOTO-AUTO         MOTO         AUTO

# %% [markdown]
# Encuentro que no hay información sobre dos víctimas en la columna VICTIMA. Por ahora dejaré esto sin realizar modificación y lo atenderé de nuevo luego de realizar el análisis al dataframe df_HV, correspondiente a la hoja VICTIMAS  extraída del documento de excel.

# %% [markdown]
# ### Verificacion de tipos de variables

# %%
df_HH.dtypes
# Out:
# ID                               object
# N_VICTIMAS                        int64
# FECHA                    datetime64[ns]
# AAAA                              int64
# MM                                int64
# DD                                int64
# HORA                             object
# HH                               object
# LUGAR_DEL_HECHO                  object
# TIPO_DE_CALLE                    object
# Calle                            object
# Cruce                              bool
# Dirección Normalizada            object
# COMUNA                            int64
# XY (CABA)                        object
# pos x                            object
# pos y                            object
# PARTICIPANTES                    object
# VICTIMA                          object
# ACUSADO                          object
# dtype: object

# %%
df_HH['ID'] = df_HH['ID'].astype(str)
df_HH['HORA'] = df_HH['HORA'].astype(str)
df_HH['HH'] = df_HH['HH']. astype(int)
df_HH['LUGAR_DEL_HECHO'] = df_HH['LUGAR_DEL_HECHO']. astype(str)
df_HH['TIPO_DE_CALLE'] = df_HH['TIPO_DE_CALLE']. astype(str)
df_HH['Calle'] = df_HH['Calle']. astype(str)
df_HH['Dirección Normalizada'] = df_HH['Dirección Normalizada']. astype(str)
df_HH['pos x'] = df_HH['pos x']. astype(float)
df_HH['pos y'] = df_HH['pos y']. astype(float)
df_HH['PARTICIPANTES'] = df_HH['PARTICIPANTES']. astype(str)
df_HH['VICTIMA'] = df_HH['VICTIMA']. astype(str)
df_HH['ACUSADO'] = df_HH['ACUSADO']. astype(str)

# %% [markdown]
# ### Cambios en los nombres de las columnas

# %%
df_HH = df_HH.rename(columns={'N_VICTIMAS': 'Cantidad víctimas',
                                'FECHA': 'Fecha',
                                'AAAA':'Año',
                                'MM':'Mes',
                                'DD':'Día',
                                'HORA': 'Hora',
                                'HH':'Hora entera',
                                'LUGAR_DEL_HECHO': 'Lugar del hecho',
                                'TIPO_DE_CALLE': 'Tipo de Calle',
                                'COMUNA': 'Comuna',
                                'pos x': 'Pos x',
                                'pos y': 'Pos y',
                                'PARTICIPANTES': 'Participantes',                      
                                'VICTIMA': 'Víctima',
                                'ACUSADO': 'Acusado'
                                })

# %%
df_HH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   Cantidad víctimas      696 non-null    int64
#  2   Fecha                  696 non-null    datetime64[ns]
#  3   Año                    696 non-null    int64
#  4   Mes                    696 non-null    int64
#  5   Día                    696 non-null    int64
#  6   Hora                   696 non-null    object
#  7   Hora entera            696 non-null    int64
#  8   Lugar del hecho        696 non-null    object
#  9   Tipo de Calle          696 non-null    object
#  10  Calle                  696 non-null    object
#  11  Cruce                  696 non-null    bool
#  12  Dirección Normalizada  696 non-null    object
#  13  Comuna                 696 non-null    int64
#  14  XY (CABA)              696 non-null    object
#  15  Pos x                  696 non-null    float64
#  16  Pos y                  696 non-null    float64
#  17  Participantes          696 non-null    object
#  18  Víctima                696 non-null    object
#  19  Acusado                696 non-null    object
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(6), object(10)
# memory usage: 104.1+ KB

# %%
#Exporto a CSV para poder continuar el trabajo luego
df_HH.to_csv('Homicidios_Hechos.csv')

# %% [markdown]
# ### Análisis exploratorio inicial y transformación de datos para dataframe de VICTIMAS (df_HV)

# %%
df_HV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             717 non-null    object
#  1   FECHA                717 non-null    datetime64[ns]
#  2   AAAA                 717 non-null    int64
#  3   MM                   717 non-null    int64
#  4   DD                   717 non-null    int64
#  5   ROL                  717 non-null    object
#  6   VICTIMA              717 non-null    object
#  7   SEXO                 717 non-null    object
#  8   EDAD                 717 non-null    object
#  9   FECHA_FALLECIMIENTO  717 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 56.1+ KB

# %%
df_HV.head(10)
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 0  2016-0001 2016-01-01  2016   1   1             CONDUCTOR    MOTO
# 1  2016-0002 2016-01-02  2016   1   2             CONDUCTOR    AUTO
# 2  2016-0003 2016-01-03  2016   1   3             CONDUCTOR    MOTO
# 3  2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 4  2016-0005 2016-01-21  2016   1  21             CONDUCTOR    MOTO
# 5  2016-0008 2016-01-24  2016   1  24             CONDUCTOR    MOTO
# 6  2016-0009 2016-01-24  2016   1  24  PASAJERO_ACOMPAÑANTE    MOTO
# 7  2016-0010 2016-01-29  2016   1  29             CONDUCTOR    MOTO
# 8  2016-0012 2016-02-08  2016   2   8             CONDUCTOR    MOTO
# 9  2016-0013 2016-02-10  2016   2  10                PEATON  PEATON
#
#         SEXO EDAD  FECHA_FALLECIMIENTO
# 0  MASCULINO   19  2016-01-01 00:00:00
# 1  MASCULINO   70  2016-01-02 00:00:00
# 2  MASCULINO   30  2016-01-03 00:00:00
# 3  MASCULINO   18                   SD
# 4  MASCULINO   29  2016-02-01 00:00:00
# 5  MASCULINO   30  2016-01-24 00:00:00
# 6  MASCULINO   29  2016-01-26 00:00:00
# 7  MASCULINO   18  2016-01-29 00:00:00
# 8  MASCULINO   22  2016-02-08 00:00:00
# 9  MASCULINO   16  2016-02-10 00:00:00

# %% [markdown]
# Analizando ambos dataframes, observo que los datos de ID, fecha y hora coinciden entre ambas hojas

# %%
df_HH.head(10)
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00   4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00   1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00   7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00   0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00   5
# 5  2016-0008           1 2016-01-24  2016   1  24  18:30:00  18
# 6  2016-0009           1 2016-01-24  2016   1  24  19:10:00  19
# 7  2016-0010           1 2016-01-29  2016   1  29  15:20:00  15
# 8  2016-0012           1 2016-02-08  2016   2   8  01:20:00   1
# 9  2016-0013           1 2016-02-10  2016   2  10  11:30:00  11
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
# 5             AV 27 DE FEBRERO Y AV ESCALADA       AVENIDA  ...     NaN
# 6               NOGOYA Y JOAQUIN V. GONZALES         CALLE  ...     NaN
# 7        AV GENERAL PAZ Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 8         AV BELGRANO Y BERNARDO DE IRIGOYEN       AVENIDA  ...     NaN
# 9                         AV ENTRE RIOS 1366       AVENIDA  ...  1366.0
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                                  NaN
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
# 5                         ESCALADA AV.
# 6                 GONZALEZ, JOAQUIN V.
# 7                  DE LOS CORRALES AV.
# 8                IRIGOYEN, BERNARDO DE
# 9                                  NaN
#
#                                Dirección Normalizada COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                ENTRE RIOS AV. 2034      1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
# 5                   27 DE FEBRERO AV. y ESCALADA AV.      8
# 6                      NOGOYA y GONZALEZ, JOAQUIN V.     11
# 7               PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 8               BELGRANO AV. e IRIGOYEN, BERNARDO DE      1
# 9                                ENTRE RIOS AV. 1366      1
#
#                                  XY (CABA)         pos x         pos y  \
# 0    Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# 5   Point (101721.59002217 93844.25656649)  -58.44451316  -34.68475866
# 6   Point (96545.87592078 102330.67262199)  -58.50095869  -34.60825440
# 7    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 8  Point (107595.35084333 101797.50052813)  -58.38048577  -34.61303893
# 9  Point (106616.41069662 100496.44662323)  -58.39114932  -34.62477387
#
#       PARTICIPANTES VICTIMA      ACUSADO
# 0         MOTO-AUTO    MOTO         AUTO
# 1    AUTO-PASAJEROS    AUTO    PASAJEROS
# 2         MOTO-AUTO    MOTO         AUTO
# 3           MOTO-SD    MOTO           SD
# 4    MOTO-PASAJEROS    MOTO    PASAJEROS
# 5  MOTO-OBJETO FIJO    MOTO  OBJETO FIJO
# 6         MOTO-AUTO    MOTO         AUTO
# 7         MOTO-AUTO    MOTO         AUTO
# 8       MOTO-CARGAS    MOTO       CARGAS
# 9       PEATON-AUTO  PEATON         AUTO
#
# [10 rows x 21 columns]

# %% [markdown]
# También observo que mientras el dataset de Hechos tiene 696 registros, el de vícitmas tiene 717. Esto se debe a que algunos accidentes tienen más de una víctima.

# %% [markdown]
# #### Revisión de datos nulos

# %%
df_HV.isnull().sum()
# Out:
# ID_hecho               0
# FECHA                  0
# AAAA                   0
# MM                     0
# DD                     0
# ROL                    0
# VICTIMA                0
# SEXO                   0
# EDAD                   0
# FECHA_FALLECIMIENTO    0
# dtype: int64

# %% [markdown]
# #### Revisión de duplicados
#
# A diferencia del dataframe anterior, no utilizo el ID para verificar duplicados, pues sé que habrá Id's duplicados en los casos en que un accidente haya tenido varias víctimas

# %%
df_HV[df_HV.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %% [markdown]
# Al navegar la hoja de cálculo puede ver en diferentes columnas el valor SD, que significa Sin Datos. Voy a revisar esto columna por columna para ver si hay algo que pueda hacer para imputar estos espacios.

# %%
df_HV[df_HV['ID_hecho']=='SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %%
df_HV[df_HV['FECHA']=='SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %%
df_HV[df_HV['AAAA']=='SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %%
df_HV[df_HV['MM']=='SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %%
df_HV[df_HV['DD']=='SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %% [markdown]
# Las columnas correspondientes al ID y las relacionadas con la fecha del accidente están completas.

# %%
df_HV[df_HV['FECHA_FALLECIMIENTO']=='SD']
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 3    2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 16   2016-0022 2016-02-21  2016   2  21  PASAJERO_ACOMPAÑANTE    MOTO
# 19   2016-0027 2016-02-28  2016   2  28  PASAJERO_ACOMPAÑANTE    AUTO
# 22   2016-0031 2016-03-08  2016   3   8             CONDUCTOR    MOTO
# 33   2016-0045 2016-04-11  2016   4  11             CONDUCTOR    MOTO
# ..         ...        ...   ...  ..  ..                   ...     ...
# 221  2017-0089 2017-07-13  2017   7  13                    SD      SD
# 242  2017-0112 2017-09-10  2017   9  10  PASAJERO_ACOMPAÑANTE    AUTO
# 246  2017-0115 2017-09-19  2017   9  19             CONDUCTOR    MOTO
# 253  2017-0126 2017-10-14  2017  10  14  PASAJERO_ACOMPAÑANTE    AUTO
# 280  2017-0155 2017-12-12  2017  12  12                    SD      SD
#
#           SEXO EDAD FECHA_FALLECIMIENTO
# 3    MASCULINO   18                  SD
# 16   MASCULINO   41                  SD
# 19   MASCULINO   34                  SD
# 22   MASCULINO   21                  SD
# 33   MASCULINO   SD                  SD
# ..         ...  ...                 ...
# 221  MASCULINO   23                  SD
# 242  MASCULINO    1                  SD
# 246  MASCULINO   34                  SD
# 253  MASCULINO   39                  SD
# 280  MASCULINO   77                  SD
#
# [68 rows x 10 columns]

# %% [markdown]
# Hay 68 registros sin fecha de fallecimiento. Tengo varias ocpiones:
# - Rellenar este valor con la fecha del accidente. Observo que el formato de fecha es diferente en ambas columnas, así que tendría que unificar este formato, eso implicaría una revisión y transformación de todos los datos de una de las columnas, uno a uno.
# - Eliminar la columna, ya que no me aporta mucho al análisis estadísitico ni a los KPI's. Sería interesante para revisar temas de rapidez de la atención médica, llegada de asistencia médica a la escena, disponibilidad de ambulancias, etc., ya que tal vez, si las víctimas no murieron en el lugar del accidente, una atención médica eficiente y oportuna podría ser determinante para salvar sus vidas; pero no es el área de enfoque de este proyecto.
#
# Me decanto por la opción de eliminar la columna.

# %%
df_HV = df_HV.drop(columns = ['FECHA_FALLECIMIENTO'])

# %%
df_HV[df_HV['ROL']=='SD']
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD ROL VICTIMA       SEXO EDAD
# 36   2016-0049 2016-04-17  2016   4  17  SD      SD         SD   SD
# 39   2016-0052 2016-04-20  2016   4  20  SD    MOTO         SD   SD
# 63   2016-0085 2016-06-29  2016   6  29  SD    MOTO  MASCULINO   SD
# 77   2016-0101 2016-08-07  2016   8   7  SD      SD  MASCULINO   67
# 89   2016-0115 2016-09-02  2016   9   2  SD      SD  MASCULINO   SD
# 141  2016-0174 2016-12-27  2016  12  27  SD      SD         SD   SD
# 167  2017-0029 2017-03-07  2017   3   7  SD      SD  MASCULINO   34
# 208  2017-0074 2017-06-04  2017   6   4  SD      SD  MASCULINO   70
# 221  2017-0089 2017-07-13  2017   7  13  SD      SD  MASCULINO   23
# 280  2017-0155 2017-12-12  2017  12  12  SD      SD  MASCULINO   77
# 390  2018-0100 2018-09-20  2018   9  20  SD    MOTO   FEMENINO   33

# %%
df_HV[df_HV['VICTIMA']=='SD']
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 36   2016-0049 2016-04-17  2016   4  17                    SD      SD
# 77   2016-0101 2016-08-07  2016   8   7                    SD      SD
# 89   2016-0115 2016-09-02  2016   9   2                    SD      SD
# 93   2016-0119 2016-09-04  2016   9   4  PASAJERO_ACOMPAÑANTE      SD
# 141  2016-0174 2016-12-27  2016  12  27                    SD      SD
# 167  2017-0029 2017-03-07  2017   3   7                    SD      SD
# 208  2017-0074 2017-06-04  2017   6   4                    SD      SD
# 221  2017-0089 2017-07-13  2017   7  13                    SD      SD
# 280  2017-0155 2017-12-12  2017  12  12                    SD      SD
#
#           SEXO EDAD
# 36          SD   SD
# 77   MASCULINO   67
# 89   MASCULINO   SD
# 93    FEMENINO   SD
# 141         SD   SD
# 167  MASCULINO   34
# 208  MASCULINO   70
# 221  MASCULINO   23
# 280  MASCULINO   77

# %%
df_HV[df_HV['SEXO']=='SD']
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA SEXO EDAD
# 36   2016-0049 2016-04-17  2016   4  17         SD      SD   SD   SD
# 39   2016-0052 2016-04-20  2016   4  20         SD    MOTO   SD   SD
# 108  2016-0136 2016-10-25  2016  10  25  CONDUCTOR    MOTO   SD   SD
# 121  2016-0151 2016-11-18  2016  11  18     PEATON  PEATON   SD   SD
# 138  2016-0171 2016-12-25  2016  12  25  CONDUCTOR    MOTO   SD   SD
# 141  2016-0174 2016-12-27  2016  12  27         SD      SD   SD   SD

# %% [markdown]
# En estas tres columnas la proporción de SD es pequeña: en ROL son 11 registros (1.5%), en VICTIMA son 9 registro (1.3%) y en SEXO son 6 registros (0.8%).
#
# Para que no queden vacíos, puedo cambiar los datos faltantes de SEXO y ROL por el valor más frecuente de cada columna, con la tranquilidad de que, al ser tan pocos datos, no voy a alterar significativamente los resultados de los análisis estadísticos.
#
# No voy a hacer ningún cambio en la columna VICTIMA, pues podría generar inconsistencia con los datos sobre la víctima que se encuentran en el dataframe de Hechos. Al hacer merge de ambos dataframes volveré a revisar este campo.

# %%
valor_mas_frecuente = df_HV['SEXO'].mode().iloc[0]
print(f'El valor mas frecuente para SEXO es: {valor_mas_frecuente}')
# Out:
# El valor mas frecuente para SEXO es: MASCULINO

# %%
df_HV['SEXO'][df_HV['SEXO']=='SD'] = 'MASCULINO'

# %%
df_HV[df_HV['SEXO']=='SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD]
# Index: []

# %%
valor_mas_frecuente = df_HV['ROL'].mode().iloc[0]
print(f'El valor mas frecuente para ROL es: {valor_mas_frecuente}')
# Out:
# El valor mas frecuente para ROL es: CONDUCTOR

# %%
df_HV['ROL'][df_HV['ROL']=='SD'] = 'CONDUCTOR'

# %%
df_HV[df_HV['ROL']=='SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD]
# Index: []

# %%
df_HV[df_HV['EDAD']=='SD'].shape[0]
# Out:
# 53

# %% [markdown]
# En la columna EDAD el número de registros sin datos es mucho mayor, aunque sigue siendo un porcentaje pequeño: son 45 registros (6.3%). Ya que dejar estos valores como SD (str) me va a generar problemas con el tipo de datos de la columna y asignarles 0 puede afectar los cálculos estadísticos, voy a tomar el promedio de edad según el sexo de las víctimas para rellenar estos faltantes.

# %%
# Reemplazo SD por Na para poder calcular el promedio
df_HV['EDAD'] = df_HV['EDAD'].replace('SD', pd.NA)

promedio_por_genero = df_HV.groupby('SEXO')['EDAD'].mean()
print(f'La edad promedio de FEMENINO es {round(promedio_por_genero["FEMENINO"])} y de MASCULINO es {round(promedio_por_genero["MASCULINO"])}')

# Se llenan los valores NaN en la columna 'edad' utilizando el promedio correspondiente al género
df_HV['EDAD'] = df_HV.apply(lambda row: promedio_por_genero[row['SEXO']] if pd.isna(row['EDAD']) else row['EDAD'], axis=1)
# Convierto de una vez el tipo de dato de esta columna a entero
df_HV['EDAD'] = df_HV['EDAD'].astype(int)
# Out:
# La edad promedio de FEMENINO es 51 y de MASCULINO es 40

# %%
df_HV[df_HV['EDAD']=='SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD]
# Index: []

# %%
df_HV.head(20)
# Out:
#      ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 0   2016-0001 2016-01-01  2016   1   1             CONDUCTOR    MOTO
# 1   2016-0002 2016-01-02  2016   1   2             CONDUCTOR    AUTO
# 2   2016-0003 2016-01-03  2016   1   3             CONDUCTOR    MOTO
# 3   2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 4   2016-0005 2016-01-21  2016   1  21             CONDUCTOR    MOTO
# 5   2016-0008 2016-01-24  2016   1  24             CONDUCTOR    MOTO
# 6   2016-0009 2016-01-24  2016   1  24  PASAJERO_ACOMPAÑANTE    MOTO
# 7   2016-0010 2016-01-29  2016   1  29             CONDUCTOR    MOTO
# 8   2016-0012 2016-02-08  2016   2   8             CONDUCTOR    MOTO
# 9   2016-0013 2016-02-10  2016   2  10                PEATON  PEATON
# 10  2016-0015 2016-02-14  2016   2  14                PEATON  PEATON
# 11  2016-0016 2016-02-14  2016   2  14  PASAJERO_ACOMPAÑANTE    MOTO
# 12  2016-0017 2016-02-15  2016   2  15                PEATON  PEATON
# 13  2016-0019 2016-02-17  2016   2  17                PEATON  PEATON
# 14  2016-0020 2016-02-17  2016   2  17                PEATON  PEATON
# 15  2016-0021 2016-02-17  2016   2  17             CONDUCTOR    AUTO
# 16  2016-0022 2016-02-21  2016   2  21  PASAJERO_ACOMPAÑANTE    MOTO
# 17  2016-0025 2016-02-28  2016   2  28  PASAJERO_ACOMPAÑANTE    AUTO
# 18  2016-0026 2016-02-28  2016   2  28             CONDUCTOR    AUTO
# 19  2016-0027 2016-02-28  2016   2  28  PASAJERO_ACOMPAÑANTE    AUTO
#
#          SEXO  EDAD
# 0   MASCULINO    19
# 1   MASCULINO    70
# 2   MASCULINO    30
# 3   MASCULINO    18
# 4   MASCULINO    29
# 5   MASCULINO    30
# 6   MASCULINO    29
# 7   MASCULINO    18
# 8   MASCULINO    22
# 9   MASCULINO    16
# 10   FEMENINO    16
# 11   FEMENINO    19
# 12  MASCULINO    59
# 13   FEMENINO    65
# 14  MASCULINO    59
# 15  MASCULINO    34
# 16  MASCULINO    41
# 17  MASCULINO    34
# 18  MASCULINO    30
# 19  MASCULINO    34

# %% [markdown]
# #### Columna VICTIMA
# Reviso si las categorías presentes en esta columna corresponden a las informadas en el Diccionario de Datos

# %%
df_HV['VICTIMA'].unique()
# Out:
# array(['MOTO', 'AUTO', 'PEATON', 'SD', 'CARGAS', 'BICICLETA', 'PASAJEROS',
#        'MOVIL'], dtype=object)

# %% [markdown]
# Encuentro que todos corresponden, no hay ningún valor diferente a los especificados.

# %% [markdown]
# #### Verificacion de tipos de variables

# %%
df_HV.dtypes
# Out:
# ID_hecho            object
# FECHA       datetime64[ns]
# AAAA                 int64
# MM                   int64
# DD                   int64
# ROL                 object
# VICTIMA             object
# SEXO                object
# EDAD                 int64
# dtype: object

# %%
df_HV['ID_hecho'] = df_HV['ID_hecho'].astype(str)
df_HV['ROL']=df_HV['ROL'].astype(str)
df_HV['VICTIMA']=df_HV['VICTIMA'].astype(str)
df_HV['SEXO']=df_HV['SEXO'].astype(str)

# %% [markdown]
# #### Cambios en los nombres de las columnas

# %%
df_HV = df_HV.rename(columns={'ID_hecho': 'ID',
                                'FECHA': 'Fecha',
                                'AAAA':'Año',
                                'MM':'Mes',
                                'DD':'Día',
                                'ROL': 'Rol',                               
                                'VICTIMA': 'Víctima',
                                'SEXO': 'Sexo',
                                'EDAD':'Edad'                                
                                })

# %%
df_HV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       717 non-null    object
#  1   Fecha    717 non-null    datetime64[ns]
#  2   Año      717 non-null    int64
#  3   Mes      717 non-null    int64
#  4   Día      717 non-null    int64
#  5   Rol      717 non-null    object
#  6   Víctima  717 non-null    object
#  7   Sexo     717 non-null    object
#  8   EDAD     717 non-null    int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 50.5+ KB

# %%
#Exporto a CSV para poder continuar el trabajo luego
df_HV.to_csv('Homicidios_Victimas.csv')

# %% [markdown]
# ### Preparación del dataset para proceso de EDA, KPI y construcción del DashBoard

# %% [markdown]
# Extraigo los datos ya limpios y transformados de los archivos CSV en los que se almacenaron anteriormente

# %%
df_hoja_hechos = pd.read_csv('Homicidios_Hechos.csv', index_col=0)
df_hoja_victimas = pd.read_csv('Homicidios_Victimas.csv', index_col=0)

# %%
df_hoja_hechos.head()
# Out:
#           ID  Cantidad víctimas       Fecha   Año  Mes  Día      Hora  \
# 0  2016-0001                  1  2016-01-01  2016    1    1  04:00:00
# 1  2016-0002                  1  2016-01-02  2016    1    2  01:15:00
# 2  2016-0003                  1  2016-01-03  2016    1    3  07:00:00
# 3  2016-0004                  1  2016-01-10  2016    1   10  00:00:00
# 4  2016-0005                  1  2016-01-21  2016    1   21  05:20:00
#
#    Hora entera                            Lugar del hecho Tipo de Calle  \
# 0            4  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA
# 1            1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ
# 2            7                         AV ENTRE RIOS 2034       AVENIDA
# 3            0      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA
# 4            5  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA
#
#               Calle  Cruce                              Dirección Normalizada  \
# 0  PIEDRA BUENA AV.   True  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...
# 1    PAZ, GRAL. AV.   True               PAZ, GRAL. AV. y DE LOS CORRALES AV.
# 2    ENTRE RIOS AV.  False                                ENTRE RIOS AV. 2034
# 3    LARRAZABAL AV.   True          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.
# 4      SAN JUAN AV.   True            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.
#
#    Comuna                                XY (CABA)      Pos x      Pos y  \
# 0       8    Point (98896.78238426 93532.43437792) -58.475340 -34.687570
# 1       9    Point (95832.05571093 95505.41641999) -58.508775 -34.669777
# 2       1   Point (106684.29090040 99706.57687843) -58.390403 -34.631894
# 3       8    Point (99840.65224780 94269.16534422) -58.465039 -34.680930
# 4       1  Point (106980.32827929 100752.16915795) -58.387183 -34.622466
#
#     Participantes Víctima    Acusado
# 0       MOTO-AUTO    MOTO       AUTO
# 1  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2       MOTO-AUTO    MOTO       AUTO
# 3         MOTO-SD    MOTO         SD
# 4  MOTO-PASAJEROS    MOTO  PASAJEROS

# %%
df_hoja_hechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 696 entries, 0 to 695
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   Cantidad víctimas      696 non-null    int64
#  2   Fecha                  696 non-null    object
#  3   Año                    696 non-null    int64
#  4   Mes                    696 non-null    int64
#  5   Día                    696 non-null    int64
#  6   Hora                   696 non-null    object
#  7   Hora entera            696 non-null    int64
#  8   Lugar del hecho        696 non-null    object
#  9   Tipo de Calle          696 non-null    object
#  10  Calle                  696 non-null    object
#  11  Cruce                  696 non-null    bool
#  12  Dirección Normalizada  696 non-null    object
#  13  Comuna                 696 non-null    int64
#  14  XY (CABA)              696 non-null    object
#  15  Pos x                  696 non-null    float64
#  16  Pos y                  696 non-null    float64
#  17  Participantes          696 non-null    object
#  18  Víctima                696 non-null    object
#  19  Acusado                696 non-null    object
# dtypes: bool(1), float64(2), int64(6), object(11)
# memory usage: 109.4+ KB

# %%
df_hoja_victimas.head()
# Out:
#           ID       Fecha   Año  Mes  Día        Rol Víctima       Sexo  EDAD
# 0  2016-0001  2016-01-01  2016    1    1  CONDUCTOR    MOTO  MASCULINO    19
# 1  2016-0002  2016-01-02  2016    1    2  CONDUCTOR    AUTO  MASCULINO    70
# 2  2016-0003  2016-01-03  2016    1    3  CONDUCTOR    MOTO  MASCULINO    30
# 3  2016-0004  2016-01-10  2016    1   10  CONDUCTOR    MOTO  MASCULINO    18
# 4  2016-0005  2016-01-21  2016    1   21  CONDUCTOR    MOTO  MASCULINO    29

# %%
df_hoja_victimas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 717 entries, 0 to 716
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       717 non-null    object
#  1   Fecha    717 non-null    object
#  2   Año      717 non-null    int64
#  3   Mes      717 non-null    int64
#  4   Día      717 non-null    int64
#  5   Rol      717 non-null    object
#  6   Víctima  717 non-null    object
#  7   Sexo     717 non-null    object
#  8   EDAD     717 non-null    int64
# dtypes: int64(4), object(5)
# memory usage: 56.0+ KB

# %% [markdown]
# Como hay columnas repetidas, voy a eliminar algunas antes de mezclar los dos dataframes

# %%
df_hoja_victimas=df_hoja_victimas.drop(columns=['Fecha', 'Año', 'Mes', 'Día'])

# %%
df_hoja_hechos=df_hoja_hechos.drop(columns=['Víctima'])

# %% [markdown]
# Realizo un merge entre ambos dataframes

# %%
df_homicidios = pd.merge(df_hoja_hechos, df_hoja_victimas, on='ID', how='inner')
df_homicidios
# Out:
#             ID  Cantidad víctimas       Fecha   Año  Mes  Día      Hora  \
# 0    2016-0001                  1  2016-01-01  2016    1    1  04:00:00
# 1    2016-0002                  1  2016-01-02  2016    1    2  01:15:00
# 2    2016-0003                  1  2016-01-03  2016    1    3  07:00:00
# 3    2016-0004                  1  2016-01-10  2016    1   10  00:00:00
# 4    2016-0005                  1  2016-01-21  2016    1   21  05:20:00
# ..         ...                ...         ...   ...  ...  ...       ...
# 712  2021-0093                  1  2021-12-13  2021   12   13  17:10:00
# 713  2021-0094                  1  2021-12-20  2021   12   20  01:10:00
# 714  2021-0095                  1  2021-12-30  2021   12   30  00:43:00
# 715  2021-0096                  1  2021-12-15  2021   12   15  10:30:00
# 716  2021-0097                  1  2021-11-18  2021   11   18  06:10:00
#
#      Hora entera                            Lugar del hecho Tipo de Calle  \
# 0              4  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA
# 1              1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ
# 2              7                         AV ENTRE RIOS 2034       AVENIDA
# 3              0      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA
# 4              5  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA
# ..           ...                                        ...           ...
# 712           17                          AV. RIESTRA Y MOM       AVENIDA
# 713            1                    AU DELLEPIANE Y LACARRA     AUTOPISTA
# 714            0                        AV. GAONA Y TERRADA       AVENIDA
# 715           10                         AV. EVA PERON 4071       AVENIDA
# 716            6                    PADRE CARLOS MUJICA 709         CALLE
#
#      ... Comuna                                XY (CABA)      Pos x  \
# 0    ...      8    Point (98896.78238426 93532.43437792) -58.475340
# 1    ...      9    Point (95832.05571093 95505.41641999) -58.508775
# 2    ...      1   Point (106684.29090040 99706.57687843) -58.390403
# 3    ...      8    Point (99840.65224780 94269.16534422) -58.465039
# 4    ...      1  Point (106980.32827929 100752.16915795) -58.387183
# ..   ...    ...                                      ...        ...
# 712  ...      7   Point (102728.60090138 98186.24929177) -58.433538
# 713  ...      9    Point (99624.29795829 97569.69801131) -58.467398
# 714  ...     11   Point (99116.45492358 101045.23284826) -58.472934
# 715  ...      9    Point (99324.54463985 97676.26932409) -58.470668
# 716  ...      1  Point (107664.16647795 104708.63962087) -58.379762
#
#          Pos y   Participantes    Acusado                   Rol    Víctima  \
# 0   -34.687570       MOTO-AUTO       AUTO             CONDUCTOR       MOTO
# 1   -34.669777  AUTO-PASAJEROS  PASAJEROS             CONDUCTOR       AUTO
# 2   -34.631894       MOTO-AUTO       AUTO             CONDUCTOR       MOTO
# 3   -34.680930         MOTO-SD         SD             CONDUCTOR       MOTO
# 4   -34.622466  MOTO-PASAJEROS  PASAJEROS             CONDUCTOR       MOTO
# ..         ...             ...        ...                   ...        ...
# 712 -34.645616       MOTO-AUTO       AUTO  PASAJERO_ACOMPAÑANTE       MOTO
# 713 -34.651178       MOTO-AUTO       AUTO  PASAJERO_ACOMPAÑANTE       MOTO
# 714 -34.619847     MOTO-CARGAS     CARGAS             CONDUCTOR       MOTO
# 715 -34.650217     AUTO-CARGAS     CARGAS             CONDUCTOR       AUTO
# 716 -34.586796  BICICLETA-AUTO       AUTO              CICLISTA  BICICLETA
#
#           Sexo EDAD
# 0    MASCULINO   19
# 1    MASCULINO   70
# 2    MASCULINO   30
# 3    MASCULINO   18
# 4    MASCULINO   29
# ..         ...  ...
# 712   FEMENINO   18
# 713   FEMENINO   43
# 714  MASCULINO   27
# 715  MASCULINO   60
# 716  MASCULINO   53
#
# [717 rows x 23 columns]

# %%
df_homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     717 non-null    object
#  1   Cantidad víctimas      717 non-null    int64
#  2   Fecha                  717 non-null    object
#  3   Año                    717 non-null    int64
#  4   Mes                    717 non-null    int64
#  5   Día                    717 non-null    int64
#  6   Hora                   717 non-null    object
#  7   Hora entera            717 non-null    int64
#  8   Lugar del hecho        717 non-null    object
#  9   Tipo de Calle          717 non-null    object
#  10  Calle                  717 non-null    object
#  11  Cruce                  717 non-null    bool
#  12  Dirección Normalizada  717 non-null    object
#  13  Comuna                 717 non-null    int64
#  14  XY (CABA)              717 non-null    object
#  15  Pos x                  717 non-null    float64
#  16  Pos y                  717 non-null    float64
#  17  Participantes          717 non-null    object
#  18  Acusado                717 non-null    object
#  19  Rol                    717 non-null    object
#  20  Víctima                717 non-null    object
#  21  Sexo                   717 non-null    object
#  22  EDAD                   717 non-null    int64
# dtypes: bool(1), float64(2), int64(7), object(13)
# memory usage: 124.1+ KB

# %% [markdown]
# Hago una verificación extra de la columna víctima, para los casos que tuvieron varias víctimas fatales. Quiero confirmar que para estos casos aparezcan varios registros con el mismo ID, correspondientes a cada una de las víctimas, y que la información sí corresponde.

# %%
df_homicidios[df_homicidios['Cantidad víctimas']>1]
# Out:
#             ID  Cantidad víctimas       Fecha   Año  Mes  Día      Hora  \
# 29   2016-0041                  2  2016-03-29  2016    3   29  11:00:00
# 30   2016-0041                  2  2016-03-29  2016    3   29  11:00:00
# 98   2016-0126                  2  2016-09-18  2016    9   18  22:45:00
# 99   2016-0126                  2  2016-09-18  2016    9   18  22:45:00
# 163  2017-0026                  2  2017-02-26  2017    2   26  05:15:00
# 164  2017-0026                  2  2017-02-26  2017    2   26  05:15:00
# 173  2017-0035                  3  2017-03-23  2017    3   23  05:00:00
# 174  2017-0035                  3  2017-03-23  2017    3   23  05:00:00
# 175  2017-0035                  3  2017-03-23  2017    3   23  05:00:00
# 176  2017-0036                  2  2017-03-29  2017    3   29  18:00:00
# 177  2017-0036                  2  2017-03-29  2017    3   29  18:00:00
# 186  2017-0050                  2  2017-04-28  2017    4   28  11:08:08
# 187  2017-0050                  2  2017-04-28  2017    4   28  11:08:08
# 237  2017-0108                  2  2017-09-02  2017    9    2  04:53:08
# 238  2017-0108                  2  2017-09-02  2017    9    2  04:53:08
# 242  2017-0112                  2  2017-09-10  2017    9   10  09:32:17
# 243  2017-0112                  2  2017-09-10  2017    9   10  09:32:17
# 253  2017-0126                  2  2017-10-14  2017   10   14  06:15:00
# 254  2017-0126                  2  2017-10-14  2017   10   14  06:15:00
# 277  2017-0153                  2  2017-12-11  2017   12   11  02:00:00
# 278  2017-0153                  2  2017-12-11  2017   12   11  02:00:00
# 300  2018-0015                  2  2018-02-06  2018    2    6  01:00:00
# 301  2018-0015                  2  2018-02-06  2018    2    6  01:00:00
# 312  2018-0026                  2  2018-03-09  2018    3    9  04:45:00
# 313  2018-0026                  2  2018-03-09  2018    3    9  04:45:00
# 325  2018-0038                  2  2018-04-20  2018    4   20  17:10:00
# 326  2018-0038                  2  2018-04-20  2018    4   20  17:10:00
# 373  2018-0085                  2  2018-08-03  2018    8    3  18:16:00
# 374  2018-0085                  2  2018-08-03  2018    8    3  18:16:00
# 387  2018-0098                  2  2018-09-09  2018    9    9  05:00:00
# 388  2018-0098                  2  2018-09-09  2018    9    9  05:00:00
# 418  2018-0128                  2  2018-11-25  2018   11   25  04:30:00
# 419  2018-0128                  2  2018-11-25  2018   11   25  04:30:00
# 444  2019-0010                  2  2019-02-02  2019    2    2  07:50:00
# 445  2019-0010                  2  2019-02-02  2019    2    2  07:50:00
# 576  2020-0038                  2  2020-08-30  2020    8   30  04:00:00
# 577  2020-0038                  2  2020-08-30  2020    8   30  04:00:00
# 602  2020-0063                  2  2020-12-05  2020   12    5  07:10:00
# 603  2020-0063                  2  2020-12-05  2020   12    5  07:10:00
# 616  2020-0077                  2  2020-12-25  2020   12   25  06:40:00
# 617  2020-0077                  2  2020-12-25  2020   12   25  06:40:00
#
#      Hora entera                                    Lugar del hecho  \
# 29            11                     AV DIRECTORIO Y RIVERA INDARTE
# 30            11                     AV DIRECTORIO Y RIVERA INDARTE
# 98            22                               IRIGOYEN Y TINOGASTA
# 99            22                               IRIGOYEN Y TINOGASTA
# 163            5                       AV. PERITO MORENO Y FOURNIER
# 164            5                       AV. PERITO MORENO Y FOURNIER
# 173            5  AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUC...
# 174            5  AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUC...
# 175            5  AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUC...
# 176           18                CURUPAYTI Y COLECTORA AV. GRAL. PAZ
# 177           18                CURUPAYTI Y COLECTORA AV. GRAL. PAZ
# 186           11            AU PERITO MORENO Y RAMAL ENLACE AU1/AU6
# 187           11            AU PERITO MORENO Y RAMAL ENLACE AU1/AU6
# 237            4                            AV. GRAL. PAZ Y MACHAIN
# 238            4                            AV. GRAL. PAZ Y MACHAIN
# 242            9                         AU 25 DE MAYO Y AV. VARELA
# 243            9                         AU 25 DE MAYO Y AV. VARELA
# 253            6                      AV. RIESTRA Y CAÑADA DE GOMEZ
# 254            6                      AV. RIESTRA Y CAÑADA DE GOMEZ
# 277            2                             ROSARIO Y AV. LA PLATA
# 278            2                             ROSARIO Y AV. LA PLATA
# 300            1                                 Australia Av. 2800
# 301            1                                 Australia Av. 2800
# 312            4     Rabanal, Francisco, Intendente Av. y Saenz Av.
# 313            4     Rabanal, Francisco, Intendente Av. y Saenz Av.
# 325           17                                 AV. RIVADAVIA 1571
# 326           17                                 AV. RIVADAVIA 1571
# 373           18                Entre Rios Av. y Garay, Juan De Av.
# 374           18                Entre Rios Av. y Garay, Juan De Av.
# 387            5          Av. Gral. Paz e/ Ferre y Beron de Astrada
# 388            5          Av. Gral. Paz e/ Ferre y Beron de Astrada
# 418            4                               Paz, Gral. Av. 11200
# 419            4                               Paz, Gral. Av. 11200
# 444            7                            DEL LIBERTADOR AV. 4100
# 445            7                            DEL LIBERTADOR AV. 4100
# 576            4            LAS HERAS GENERAL AV. Y DIAZ, CNEL. AV.
# 577            4            LAS HERAS GENERAL AV. Y DIAZ, CNEL. AV.
# 602            7                           NUEVA YORK Y ALTA GRACIA
# 603            7                           NUEVA YORK Y ALTA GRACIA
# 616            6                      SAN MARTIN AV. Y PUNTA ARENAS
# 617            6                      SAN MARTIN AV. Y PUNTA ARENAS
#
#     Tipo de Calle  ... Comuna                                XY (CABA)  \
# 29        AVENIDA  ...      7   Point (100232.38564985 99530.25843190)
# 30        AVENIDA  ...      7   Point (100232.38564985 99530.25843190)
# 98          CALLE  ...     10   Point (94275.54271123 100886.87954649)
# 99          CALLE  ...     10   Point (94275.54271123 100886.87954649)
# 163       AVENIDA  ...      4   Point (104113.67806500 97722.68219304)
# 164       AVENIDA  ...      4   Point (104113.67806500 97722.68219304)
# 173       AVENIDA  ...      1  Point (109583.11620052 102006.72069921)
# 174       AVENIDA  ...      1  Point (109583.11620052 102006.72069921)
# 175       AVENIDA  ...      1  Point (109583.11620052 102006.72069921)
# 176      GRAL PAZ  ...     12   Point (95300.18060161 105287.23850698)
# 177      GRAL PAZ  ...     12   Point (95300.18060161 105287.23850698)
# 186     AUTOPISTA  ...      9                                        0
# 187     AUTOPISTA  ...      9                                        0
# 237      GRAL PAZ  ...     12   Point (97098.48468623 109019.96106626)
# 238      GRAL PAZ  ...     12   Point (97098.48468623 109019.96106626)
# 242     AUTOPISTA  ...      7   Point (100479.14412395 98812.52258620)
# 243     AUTOPISTA  ...      7   Point (100479.14412395 98812.52258620)
# 253       AVENIDA  ...      8    Point (98466.20276785 94207.42419155)
# 254       AVENIDA  ...      8    Point (98466.20276785 94207.42419155)
# 277       AVENIDA  ...      6  Point (103186.65733155 101217.09689755)
# 278       AVENIDA  ...      6  Point (103186.65733155 101217.09689755)
# 300       AVENIDA  ...      4   Point (107053.47849253 98047.93724144)
# 301       AVENIDA  ...      4   Point (107053.47849253 98047.93724144)
# 312       AVENIDA  ...      4   Point (104283.01090451 97171.08656182)
# 313       AVENIDA  ...      4   Point (104283.01090451 97171.08656182)
# 325       AVENIDA  ...      1  Point (106840.31999667 102262.72809661)
# 326       AVENIDA  ...      1  Point (106840.31999667 102262.72809661)
# 373       AVENIDA  ...      3  Point (106612.54991859 100244.75667446)
# 374       AVENIDA  ...      3  Point (106612.54991859 100244.75667446)
# 387      GRAL PAZ  ...      8    Point (99203.46279192 92552.75548716)
# 388      GRAL PAZ  ...      8    Point (99203.46279192 92552.75548716)
# 418      GRAL PAZ  ...      9    Point (94027.41355272 98150.01779732)
# 419      GRAL PAZ  ...      9    Point (94027.41355272 98150.01779732)
# 444       AVENIDA  ...     14  Point (103359.87920798 106617.17056502)
# 445       AVENIDA  ...     14  Point (103359.87920798 106617.17056502)
# 576       AVENIDA  ...     14  Point (105241.05562982 105080.52102657)
# 577       AVENIDA  ...     14  Point (105241.05562982 105080.52102657)
# 602         CALLE  ...     11   Point (94080.62190808 102083.62453795)
# 603         CALLE  ...     11   Point (94080.62190808 102083.62453795)
# 616       AVENIDA  ...     15   Point (99182.71320106 103123.43585183)
# 617       AVENIDA  ...     15   Point (99182.71320106 103123.43585183)
#
#          Pos x      Pos y     Participantes      Acusado  \
# 29  -58.460766 -34.633504       MOTO-CARGAS       CARGAS
# 30  -58.460766 -34.633504       MOTO-CARGAS       CARGAS
# 98  -58.525721 -34.621259       AUTO-CARGAS       CARGAS
# 99  -58.525721 -34.621259       AUTO-CARGAS       CARGAS
# 163 -58.418428 -34.649791  AUTO-OBJETO FIJO  OBJETO FIJO
# 164 -58.418428 -34.649791  AUTO-OBJETO FIJO  OBJETO FIJO
# 173 -58.358815 -34.611136  AUTO-OBJETO FIJO  OBJETO FIJO
# 174 -58.358815 -34.611136  AUTO-OBJETO FIJO  OBJETO FIJO
# 175 -58.358815 -34.611136  AUTO-OBJETO FIJO  OBJETO FIJO
# 176 -58.514523 -34.581598    MOTO-PASAJEROS    PASAJEROS
# 177 -58.514523 -34.581598    MOTO-PASAJEROS    PASAJEROS
# 186   0.000000   0.000000       MOTO-CARGAS       CARGAS
# 187   0.000000   0.000000       MOTO-CARGAS       CARGAS
# 237 -58.494911 -34.547956  AUTO-OBJETO FIJO         AUTO
# 238 -58.494911 -34.547956  AUTO-OBJETO FIJO         AUTO
# 242 -58.458074 -34.639974  AUTO-OBJETO FIJO  OBJETO FIJO
# 243 -58.458074 -34.639974  AUTO-OBJETO FIJO  OBJETO FIJO
# 253 -58.480037 -34.681485  AUTO-OBJETO FIJO  OBJETO FIJO
# 254 -58.480037 -34.681485  AUTO-OBJETO FIJO  OBJETO FIJO
# 277 -58.428553 -34.618294    MOTO-PASAJEROS    PASAJEROS
# 278 -58.428553 -34.618294    MOTO-PASAJEROS    PASAJEROS
# 300 -58.386363 -34.646843    MOTO-PASAJEROS    PASAJEROS
# 301 -58.386363 -34.646843    MOTO-PASAJEROS    PASAJEROS
# 312 -58.416578 -34.654762      MOVIL-CARGAS       CARGAS
# 313 -58.416578 -34.654762      MOVIL-CARGAS       CARGAS
# 325 -58.388722 -34.608850       PEATON-AUTO         AUTO
# 326 -58.388722 -34.608850       PEATON-AUTO         AUTO
# 373 -58.391189 -34.627043    MOTO-PASAJEROS    PASAJEROS
# 374 -58.391189 -34.627043    MOTO-PASAJEROS    PASAJEROS
# 387 -58.471994 -34.696402         AUTO-AUTO         AUTO
# 388 -58.471994 -34.696402         AUTO-AUTO         AUTO
# 418 -58.528446 -34.645929    AUTO-PASAJEROS    PASAJEROS
# 419 -58.528446 -34.645929    AUTO-PASAJEROS    PASAJEROS
# 444 -58.426685 -34.569615       PEATON-AUTO         AUTO
# 445 -58.426685 -34.569615       PEATON-AUTO         AUTO
# 576 -58.406175 -34.583459         AUTO-AUTO         AUTO
# 577 -58.406175 -34.583459         AUTO-AUTO         AUTO
# 602 -58.527838 -34.610470  PEATON_MOTO-MOTO         MOTO
# 603 -58.527838 -34.610470  PEATON_MOTO-MOTO         MOTO
# 616 -58.472209 -34.601114         MOTO-AUTO         AUTO
# 617 -58.472209 -34.601114         MOTO-AUTO         AUTO
#
#                       Rol Víctima       Sexo EDAD
# 29              CONDUCTOR    MOTO  MASCULINO   54
# 30   PASAJERO_ACOMPAÑANTE    MOTO  MASCULINO   39
# 98              CONDUCTOR    AUTO  MASCULINO   37
# 99   PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO   60
# 163  PASAJERO_ACOMPAÑANTE    AUTO   FEMENINO   23
# 164             CONDUCTOR    AUTO  MASCULINO   19
# 173             CONDUCTOR    AUTO  MASCULINO   28
# 174  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO   32
# 175  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO   30
# 176  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO   50
# 177             CONDUCTOR    MOTO  MASCULINO   20
# 186             CONDUCTOR    MOTO  MASCULINO   46
# 187  PASAJERO_ACOMPAÑANTE    MOTO  MASCULINO   16
# 237  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO   17
# 238  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO   10
# 242  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO    1
# 243  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO   39
# 253  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO   39
# 254             CONDUCTOR    AUTO  MASCULINO   36
# 277  PASAJERO_ACOMPAÑANTE    MOTO  MASCULINO   39
# 278             CONDUCTOR    MOTO  MASCULINO   30
# 300             CONDUCTOR    MOTO  MASCULINO   28
# 301  PASAJERO_ACOMPAÑANTE    MOTO  MASCULINO   19
# 312             CONDUCTOR   MOVIL  MASCULINO   24
# 313  PASAJERO_ACOMPAÑANTE   MOVIL  MASCULINO   30
# 325                PEATON  PEATON   FEMENINO   59
# 326                PEATON  PEATON  MASCULINO   61
# 373  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO   22
# 374             CONDUCTOR    MOTO  MASCULINO   30
# 387             CONDUCTOR    AUTO  MASCULINO   55
# 388  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO   54
# 418  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO   49
# 419  PASAJERO_ACOMPAÑANTE    AUTO   FEMENINO   39
# 444                PEATON  PEATON  MASCULINO   39
# 445                PEATON  PEATON  MASCULINO   59
# 576             CONDUCTOR    AUTO  MASCULINO   46
# 577             CONDUCTOR    AUTO  MASCULINO   64
# 602                PEATON  PEATON  MASCULINO   38
# 603  PASAJERO_ACOMPAÑANTE    MOTO  MASCULINO   21
# 616             CONDUCTOR    MOTO   FEMENINO   30
# 617  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO   24
#
# [41 rows x 23 columns]

# %% [markdown]
# Este dataset está listo para pasar a la fase de EDA, elaborar los KPI's y llevar a un dashboard

# %%
#Exporto a CSV para poder continuar el trabajo luego
df_homicidios.to_csv('homicidios_completo.csv')

# %% [markdown]
# ## Base de datos Población CABA

# %% [markdown]
# En la página web del censo 2022 del Gobierno Argentino, encontré un documento en excel llamado Cuadro 1.1. Ciudad Autónoma de Buenos Aires. Total de población, variación absoluta y variación relativa, por comuna. Años 2010 y 2022.
#
# Creé una copia en excel de este documento y, utilizando la información de la variación absoluta y relativa, obtuve los valores proyectados para la población de los años 2017 a 2021. Este documento extendido es el que voy a utilizar a continuación en el proceso de calcular los KPIs

# %%
df_poblacion = pd.read_excel('Poblacion_CABA.xlsx')
df_poblacion
# Out:
#    Comuna  Población 2010  Población 2022  Variación absoluta  \
# 0    CABA         2890151         3121707              231556
# 1       1          205886          223554               17668
# 2       2          157932          161645                3713
# 3       3          187537          196240                8703
# 4       4          218245          229240               10995
# 5       5          179005          194271               15266
# 6       6          176076          203043               26967
# 7       7          220591          215896               -4695
# 8       8          187237          204367               17130
# 9       9          161797          169063                7266
# 10     10          166022          173004                6982
# 11     11          189832          204601               14769
# 12     12          200116          236887               36771
# 13     13          231331          264385               33054
# 14     14          225970          248635               22665
# 15     15          182574          196876               14302
#
#     Variación relativa (%)  Aumento población/año  Población 2016  \
# 0                      8.0           19296.333333       3005929.0
# 1                      8.6            1472.333333        214720.0
# 2                      2.4             309.416667        159788.5
# 3                      4.6             725.250000        191888.5
# 4                      5.0             916.250000        223742.5
# 5                      8.5            1272.166667        186638.0
# 6                     15.3            2247.250000        189559.5
# 7                     -2.1            -391.250000        218243.5
# 8                      9.1            1427.500000        195802.0
# 9                      4.5             605.500000        165430.0
# 10                     4.2             581.833333        169513.0
# 11                     7.8            1230.750000        197216.5
# 12                    18.4            3064.250000        218501.5
# 13                    14.3            2754.500000        247858.0
# 14                    10.0            1888.750000        237302.5
# 15                     7.8            1191.833333        189725.0
#
#     Población 2017  Población 2018  Población 2019  Población 2020  \
# 0     3.025225e+06    3.044522e+06      3063818.00    3.083114e+06
# 1     2.161923e+05    2.176647e+05       219137.00    2.206093e+05
# 2     1.600979e+05    1.604073e+05       160716.75    1.610262e+05
# 3     1.926138e+05    1.933390e+05       194064.25    1.947895e+05
# 4     2.246588e+05    2.255750e+05       226491.25    2.274075e+05
# 5     1.879102e+05    1.891823e+05       190454.50    1.917267e+05
# 6     1.918068e+05    1.940540e+05       196301.25    1.985485e+05
# 7     2.178522e+05    2.174610e+05       217069.75    2.166785e+05
# 8     1.972295e+05    1.986570e+05       200084.50    2.015120e+05
# 9     1.660355e+05    1.666410e+05       167246.50    1.678520e+05
# 10    1.700948e+05    1.706767e+05       171258.50    1.718403e+05
# 11    1.984472e+05    1.996780e+05       200908.75    2.021395e+05
# 12    2.215658e+05    2.246300e+05       227694.25    2.307585e+05
# 13    2.506125e+05    2.533670e+05       256121.50    2.588760e+05
# 14    2.391912e+05    2.410800e+05       242968.75    2.448575e+05
# 15    1.909168e+05    1.921087e+05       193300.50    1.944923e+05
#
#     Población 2021
# 0     3.102411e+06
# 1     2.220817e+05
# 2     1.613356e+05
# 3     1.955148e+05
# 4     2.283238e+05
# 5     1.929988e+05
# 6     2.007958e+05
# 7     2.162872e+05
# 8     2.029395e+05
# 9     1.684575e+05
# 10    1.724222e+05
# 11    2.033702e+05
# 12    2.338228e+05
# 13    2.616305e+05
# 14    2.467462e+05
# 15    1.956842e+05

# %%
df_poblacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Comuna                  16 non-null     object
#  1   Población 2010          16 non-null     int64
#  2   Población 2022          16 non-null     int64
#  3   Variación absoluta      16 non-null     int64
#  4   Variación relativa (%)  16 non-null     float64
#  5   Aumento población/año   16 non-null     float64
#  6   Población 2016          16 non-null     float64
#  7   Población 2017          16 non-null     float64
#  8   Población 2018          16 non-null     float64
#  9   Población 2019          16 non-null     float64
#  10  Población 2020          16 non-null     float64
#  11  Población 2021          16 non-null     float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 1.6+ KB

# %% [markdown]
# # KPI'S

# %% [markdown]
# Se nos ha pedido calcular los siguientes KPI:
# 1. Reducir en un 10% la tasa de homicidios en siniestros viales de los últimos seis meses, en CABA, en comparación con la tasa de homicidios en siniestros viales del semestre anterior.
#
# Definimos a la tasa de homicidios en siniestros viales como el número de víctimas fatales en accidentes de tránsito por cada 100,000 habitantes en un área geográfica durante un período de tiempo específico. Su fórmula es: (Número de homicidios en siniestros viales / Población total) * 100,000
#
# 2. Reducir en un 7% la cantidad de accidentes mortales de motociclistas en el último año, en CABA, respecto al año anterior.
#
# Definimos a la cantidad de accidentes mortales de motociclistas en siniestros viales como el número absoluto de accidentes fatales en los que estuvieron involucradas víctimas que viajaban en moto en un determinado periodo temporal. Su fórmula para medir la evolución de los accidentes mortales con víctimas en moto es: (Número de accidentes mortales con víctimas en moto en el año anterior - Número de accidentes mortales con víctimas en moto en el año actual) / (Número de accidentes mortales con víctimas en moto en el año anterior) * 100

# %% [markdown]
# A partir de la base de datos de población y la de homicidios voy a extraer la información necesaria para hacer los calculos correspondientes

# %%
df_homicidios= pd.read_csv('homicidios_completo.csv')
df_homicidios
# Out:
#      Unnamed: 0         ID  Cantidad víctimas       Fecha   Año  Mes  Día  \
# 0             0  2016-0001                  1  2016-01-01  2016    1    1
# 1             1  2016-0002                  1  2016-01-02  2016    1    2
# 2             2  2016-0003                  1  2016-01-03  2016    1    3
# 3             3  2016-0004                  1  2016-01-10  2016    1   10
# 4             4  2016-0005                  1  2016-01-21  2016    1   21
# ..          ...        ...                ...         ...   ...  ...  ...
# 712         712  2021-0093                  1  2021-12-13  2021   12   13
# 713         713  2021-0094                  1  2021-12-20  2021   12   20
# 714         714  2021-0095                  1  2021-12-30  2021   12   30
# 715         715  2021-0096                  1  2021-12-15  2021   12   15
# 716         716  2021-0097                  1  2021-11-18  2021   11   18
#
#          Hora  Hora entera                            Lugar del hecho  ...  \
# 0    04:00:00            4  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ  ...
# 1    01:15:00            1          AV GRAL PAZ  Y AV DE LOS CORRALES  ...
# 2    07:00:00            7                         AV ENTRE RIOS 2034  ...
# 3    00:00:00            0      AV LARRAZABAL Y GRAL VILLEGAS CONRADO  ...
# 4    05:20:00            5  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA   ...
# ..        ...          ...                                        ...  ...
# 712  17:10:00           17                          AV. RIESTRA Y MOM  ...
# 713  01:10:00            1                    AU DELLEPIANE Y LACARRA  ...
# 714  00:43:00            0                        AV. GAONA Y TERRADA  ...
# 715  10:30:00           10                         AV. EVA PERON 4071  ...
# 716  06:10:00            6                    PADRE CARLOS MUJICA 709  ...
#
#     Comuna                                XY (CABA)      Pos x      Pos y  \
# 0        8    Point (98896.78238426 93532.43437792) -58.475340 -34.687570
# 1        9    Point (95832.05571093 95505.41641999) -58.508775 -34.669777
# 2        1   Point (106684.29090040 99706.57687843) -58.390403 -34.631894
# 3        8    Point (99840.65224780 94269.16534422) -58.465039 -34.680930
# 4        1  Point (106980.32827929 100752.16915795) -58.387183 -34.622466
# ..     ...                                      ...        ...        ...
# 712      7   Point (102728.60090138 98186.24929177) -58.433538 -34.645616
# 713      9    Point (99624.29795829 97569.69801131) -58.467398 -34.651178
# 714     11   Point (99116.45492358 101045.23284826) -58.472934 -34.619847
# 715      9    Point (99324.54463985 97676.26932409) -58.470668 -34.650217
# 716      1  Point (107664.16647795 104708.63962087) -58.379762 -34.586796
#
#       Participantes    Acusado                   Rol    Víctima       Sexo  \
# 0         MOTO-AUTO       AUTO             CONDUCTOR       MOTO  MASCULINO
# 1    AUTO-PASAJEROS  PASAJEROS             CONDUCTOR       AUTO  MASCULINO
# 2         MOTO-AUTO       AUTO             CONDUCTOR       MOTO  MASCULINO
# 3           MOTO-SD         SD             CONDUCTOR       MOTO  MASCULINO
# 4    MOTO-PASAJEROS  PASAJEROS             CONDUCTOR       MOTO  MASCULINO
# ..              ...        ...                   ...        ...        ...
# 712       MOTO-AUTO       AUTO  PASAJERO_ACOMPAÑANTE       MOTO   FEMENINO
# 713       MOTO-AUTO       AUTO  PASAJERO_ACOMPAÑANTE       MOTO   FEMENINO
# 714     MOTO-CARGAS     CARGAS             CONDUCTOR       MOTO  MASCULINO
# 715     AUTO-CARGAS     CARGAS             CONDUCTOR       AUTO  MASCULINO
# 716  BICICLETA-AUTO       AUTO              CICLISTA  BICICLETA  MASCULINO
#
#     EDAD
# 0     19
# 1     70
# 2     30
# 3     18
# 4     29
# ..   ...
# 712   18
# 713   43
# 714   27
# 715   60
# 716   53
#
# [717 rows x 24 columns]

# %%
df_homicidios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             717 non-null    int64
#  1   ID                     717 non-null    object
#  2   Cantidad víctimas      717 non-null    int64
#  3   Fecha                  717 non-null    object
#  4   Año                    717 non-null    int64
#  5   Mes                    717 non-null    int64
#  6   Día                    717 non-null    int64
#  7   Hora                   717 non-null    object
#  8   Hora entera            717 non-null    int64
#  9   Lugar del hecho        717 non-null    object
#  10  Tipo de Calle          717 non-null    object
#  11  Calle                  717 non-null    object
#  12  Cruce                  717 non-null    bool
#  13  Dirección Normalizada  717 non-null    object
#  14  Comuna                 717 non-null    int64
#  15  XY (CABA)              717 non-null    object
#  16  Pos x                  717 non-null    float64
#  17  Pos y                  717 non-null    float64
#  18  Participantes          717 non-null    object
#  19  Acusado                717 non-null    object
#  20  Rol                    717 non-null    object
#  21  Víctima                717 non-null    object
#  22  Sexo                   717 non-null    object
#  23  EDAD                   717 non-null    int64
# dtypes: bool(1), float64(2), int64(8), object(13)
# memory usage: 129.7+ KB

# %% [markdown]
# #### Para calcular el primer KPI necesito obtener la cantidad de muertes correspondientes a cada semestre de los años registrados, del dataframe df_homicidios

# %%
#Creo una columna semestre para hacer más fácil el cálculo
def determinar_semestre(mes):
    if 1 <= mes <= 6:
        return 1
    elif 7 <= mes <= 12:
        return 2
    else:
        return 'Mes no válido'

# Aplicar la función a la columna 'meses' y crear una nueva columna 'semestre'
df_homicidios['Semestre'] = df_homicidios['Mes'].apply(determinar_semestre)

# %%
df_homicidios
# Out:
#      Unnamed: 0         ID  Cantidad víctimas       Fecha   Año  Mes  Día  \
# 0             0  2016-0001                  1  2016-01-01  2016    1    1
# 1             1  2016-0002                  1  2016-01-02  2016    1    2
# 2             2  2016-0003                  1  2016-01-03  2016    1    3
# 3             3  2016-0004                  1  2016-01-10  2016    1   10
# 4             4  2016-0005                  1  2016-01-21  2016    1   21
# ..          ...        ...                ...         ...   ...  ...  ...
# 712         712  2021-0093                  1  2021-12-13  2021   12   13
# 713         713  2021-0094                  1  2021-12-20  2021   12   20
# 714         714  2021-0095                  1  2021-12-30  2021   12   30
# 715         715  2021-0096                  1  2021-12-15  2021   12   15
# 716         716  2021-0097                  1  2021-11-18  2021   11   18
#
#          Hora  Hora entera                            Lugar del hecho  ...  \
# 0    04:00:00            4  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ  ...
# 1    01:15:00            1          AV GRAL PAZ  Y AV DE LOS CORRALES  ...
# 2    07:00:00            7                         AV ENTRE RIOS 2034  ...
# 3    00:00:00            0      AV LARRAZABAL Y GRAL VILLEGAS CONRADO  ...
# 4    05:20:00            5  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA   ...
# ..        ...          ...                                        ...  ...
# 712  17:10:00           17                          AV. RIESTRA Y MOM  ...
# 713  01:10:00            1                    AU DELLEPIANE Y LACARRA  ...
# 714  00:43:00            0                        AV. GAONA Y TERRADA  ...
# 715  10:30:00           10                         AV. EVA PERON 4071  ...
# 716  06:10:00            6                    PADRE CARLOS MUJICA 709  ...
#
#                                    XY (CABA)      Pos x      Pos y  \
# 0      Point (98896.78238426 93532.43437792) -58.475340 -34.687570
# 1      Point (95832.05571093 95505.41641999) -58.508775 -34.669777
# 2     Point (106684.29090040 99706.57687843) -58.390403 -34.631894
# 3      Point (99840.65224780 94269.16534422) -58.465039 -34.680930
# 4    Point (106980.32827929 100752.16915795) -58.387183 -34.622466
# ..                                       ...        ...        ...
# 712   Point (102728.60090138 98186.24929177) -58.433538 -34.645616
# 713    Point (99624.29795829 97569.69801131) -58.467398 -34.651178
# 714   Point (99116.45492358 101045.23284826) -58.472934 -34.619847
# 715    Point (99324.54463985 97676.26932409) -58.470668 -34.650217
# 716  Point (107664.16647795 104708.63962087) -58.379762 -34.586796
#
#       Participantes    Acusado                   Rol    Víctima       Sexo  \
# 0         MOTO-AUTO       AUTO             CONDUCTOR       MOTO  MASCULINO
# 1    AUTO-PASAJEROS  PASAJEROS             CONDUCTOR       AUTO  MASCULINO
# 2         MOTO-AUTO       AUTO             CONDUCTOR       MOTO  MASCULINO
# 3           MOTO-SD         SD             CONDUCTOR       MOTO  MASCULINO
# 4    MOTO-PASAJEROS  PASAJEROS             CONDUCTOR       MOTO  MASCULINO
# ..              ...        ...                   ...        ...        ...
# 712       MOTO-AUTO       AUTO  PASAJERO_ACOMPAÑANTE       MOTO   FEMENINO
# 713       MOTO-AUTO       AUTO  PASAJERO_ACOMPAÑANTE       MOTO   FEMENINO
# 714     MOTO-CARGAS     CARGAS             CONDUCTOR       MOTO  MASCULINO
# 715     AUTO-CARGAS     CARGAS             CONDUCTOR       AUTO  MASCULINO
# 716  BICICLETA-AUTO       AUTO              CICLISTA  BICICLETA  MASCULINO
#
#     EDAD Semestre
# 0     19        1
# 1     70        1
# 2     30        1
# 3     18        1
# 4     29        1
# ..   ...      ...
# 712   18        2
# 713   43        2
# 714   27        2
# 715   60        2
# 716   53        2
#
# [717 rows x 25 columns]

# %%
#agrupo por año y por semestre para determinar la cantidad de víctimas

df_victimas_por_semestre= df_homicidios.groupby(['Año', 'Semestre'])['Cantidad víctimas'].count().reset_index()
df_victimas_por_semestre
# Out:
#      Año  Semestre  Cantidad víctimas
# 0   2016         1                 65
# 1   2016         2                 81
# 2   2017         1                 69
# 3   2017         2                 71
# 4   2018         1                 70
# 5   2018         2                 79
# 6   2019         1                 57
# 7   2019         2                 47
# 8   2020         1                 31
# 9   2020         2                 50
# 10  2021         1                 55
# 11  2021         2                 42

# %%
#me aseguro de que el tipo de dato de la columna Año sea entero para poder hacer el merge sin problema
df_victimas_por_semestre['Año'] = df_victimas_por_semestre['Año'].astype(int)

# %%
df_victimas_por_semestre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Año                12 non-null     int64
#  1   Semestre           12 non-null     int64
#  2   Cantidad víctimas  12 non-null     int64
# dtypes: int64(3)
# memory usage: 420.0 bytes

# %% [markdown]
# Ahora debo extraer la información de la población total de CABA de cada año, del dataframe df_poblacion

# %%
#Extraigo la información de población para cada año
df_poblacion_total= df_poblacion[['Población 2016','Población 2017', 'Población 2018','Población 2019', 
                                  'Población 2020', 'Población 2021']]

df_poblacion_total

#cambio nombres de las columnas
df_poblacion_total = df_poblacion_total.rename(columns={'Población 2016':'2016',
                                                        'Población 2017': '2017', 
                                                        'Población 2018': '2018',
                                                        'Población 2019': '2019', 
                                                        'Población 2020': '2020', 
                                                        'Población 2021': '2021'                  
                                                        })

# %%
#Me quedo sólo con los valores de la primera fila que son los valores totales
df_poblacion_total = df_poblacion_total[:1]
df_poblacion_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2016    1 non-null      float64
#  1   2017    1 non-null      float64
#  2   2018    1 non-null      float64
#  3   2019    1 non-null      float64
#  4   2020    1 non-null      float64
#  5   2021    1 non-null      float64
# dtypes: float64(6)
# memory usage: 180.0 bytes

# %%
#modifico la orientacíon del dataframe para que quede en el formato de filas y columnas que necesito
df_poblacion_anios = pd.melt(df_poblacion_total, var_name='Año', value_name='Población Total').sort_values(by='Año')

# %%
df_poblacion_anios
# Out:
#     Año  Población Total
# 0  2016     3.005929e+06
# 1  2017     3.025225e+06
# 2  2018     3.044522e+06
# 3  2019     3.063818e+06
# 4  2020     3.083114e+06
# 5  2021     3.102411e+06

# %%
#me aseguro de que el tipo de dato de la columna Año sea entero para poder hacer el merge sin problema
df_poblacion_anios['Año'] = df_poblacion_anios['Año'].astype(int)

# %%
df_poblacion_anios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Año              6 non-null      int64
#  1   Población Total  6 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 228.0 bytes

# %%
#uno ambas tablas
df_kpi1 = pd.merge(df_victimas_por_semestre, df_poblacion_anios, on='Año', how='left')
df_kpi1
# Out:
#      Año  Semestre  Cantidad víctimas  Población Total
# 0   2016         1                 65     3.005929e+06
# 1   2016         2                 81     3.005929e+06
# 2   2017         1                 69     3.025225e+06
# 3   2017         2                 71     3.025225e+06
# 4   2018         1                 70     3.044522e+06
# 5   2018         2                 79     3.044522e+06
# 6   2019         1                 57     3.063818e+06
# 7   2019         2                 47     3.063818e+06
# 8   2020         1                 31     3.083114e+06
# 9   2020         2                 50     3.083114e+06
# 10  2021         1                 55     3.102411e+06
# 11  2021         2                 42     3.102411e+06

# %%
#añado una columna con la tasa de homicidios para cada semestre
df_kpi1['Tasa semestral'] = df_kpi1['Cantidad víctimas']*100000/df_kpi1['Población Total']
df_kpi1
# Out:
#      Año  Semestre  Cantidad víctimas  Población Total  Tasa semestral
# 0   2016         1                 65     3.005929e+06        2.162393
# 1   2016         2                 81     3.005929e+06        2.694674
# 2   2017         1                 69     3.025225e+06        2.280822
# 3   2017         2                 71     3.025225e+06        2.346933
# 4   2018         1                 70     3.044522e+06        2.299212
# 5   2018         2                 79     3.044522e+06        2.594825
# 6   2019         1                 57     3.063818e+06        1.860424
# 7   2019         2                 47     3.063818e+06        1.534034
# 8   2020         1                 31     3.083114e+06        1.005477
# 9   2020         2                 50     3.083114e+06        1.621737
# 10  2021         1                 55     3.102411e+06        1.772815
# 11  2021         2                 42     3.102411e+06        1.353786

# %%
#exporto este dataframe a csv para ser utilizado en Tabelau para elaborar el dashboard
df_kpi1.to_csv('data_kpi01.csv')

# %% [markdown]
# #### Para calcular el segundo KPI necesito obtener la cantidad de muertes de motociclistas ocurridas, en cada año, del dataframe df_homicidios

# %%
#selecciono todos los registros en los que la víctima iba en MOTO
df_motociclistas = df_homicidios[df_homicidios['Víctima']=='MOTO']
df_motociclistas
# Out:
#      Unnamed: 0         ID  Cantidad víctimas       Fecha   Año  Mes  Día  \
# 0             0  2016-0001                  1  2016-01-01  2016    1    1
# 2             2  2016-0003                  1  2016-01-03  2016    1    3
# 3             3  2016-0004                  1  2016-01-10  2016    1   10
# 4             4  2016-0005                  1  2016-01-21  2016    1   21
# 5             5  2016-0008                  1  2016-01-24  2016    1   24
# ..          ...        ...                ...         ...   ...  ...  ...
# 708         708  2021-0089                  1  2021-12-02  2021   12    2
# 710         710  2021-0091                  1  2021-12-11  2021   12   11
# 712         712  2021-0093                  1  2021-12-13  2021   12   13
# 713         713  2021-0094                  1  2021-12-20  2021   12   20
# 714         714  2021-0095                  1  2021-12-30  2021   12   30
#
#          Hora  Hora entera                            Lugar del hecho  ...  \
# 0    04:00:00            4  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ  ...
# 2    07:00:00            7                         AV ENTRE RIOS 2034  ...
# 3    00:00:00            0      AV LARRAZABAL Y GRAL VILLEGAS CONRADO  ...
# 4    05:20:00            5  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA   ...
# 5    18:30:00           18             AV 27 DE FEBRERO Y AV ESCALADA  ...
# ..        ...          ...                                        ...  ...
# 708  01:10:00            1                             AV. GAONA 3655  ...
# 710  23:00:00           23                    BAIGORRIA Y VICTOR HUGO  ...
# 712  17:10:00           17                          AV. RIESTRA Y MOM  ...
# 713  01:10:00            1                    AU DELLEPIANE Y LACARRA  ...
# 714  00:43:00            0                        AV. GAONA Y TERRADA  ...
#
#                                    XY (CABA)      Pos x      Pos y  \
# 0      Point (98896.78238426 93532.43437792) -58.475340 -34.687570
# 2     Point (106684.29090040 99706.57687843) -58.390403 -34.631894
# 3      Point (99840.65224780 94269.16534422) -58.465039 -34.680930
# 4    Point (106980.32827929 100752.16915795) -58.387183 -34.622466
# 5     Point (101721.59002217 93844.25656649) -58.444513 -34.684759
# ..                                       ...        ...        ...
# 708   Point (98804.41713890 100872.30706871) -58.476337 -34.621406
# 710   Point (94810.03686085 100710.80080255) -58.519894 -34.622849
# 712   Point (102728.60090138 98186.24929177) -58.433538 -34.645616
# 713    Point (99624.29795829 97569.69801131) -58.467398 -34.651178
# 714   Point (99116.45492358 101045.23284826) -58.472934 -34.619847
#
#         Participantes      Acusado                   Rol  Víctima       Sexo  \
# 0           MOTO-AUTO         AUTO             CONDUCTOR     MOTO  MASCULINO
# 2           MOTO-AUTO         AUTO             CONDUCTOR     MOTO  MASCULINO
# 3             MOTO-SD           SD             CONDUCTOR     MOTO  MASCULINO
# 4      MOTO-PASAJEROS    PASAJEROS             CONDUCTOR     MOTO  MASCULINO
# 5    MOTO-OBJETO FIJO  OBJETO FIJO             CONDUCTOR     MOTO  MASCULINO
# ..                ...          ...                   ...      ...        ...
# 708         MOTO-AUTO         AUTO             CONDUCTOR     MOTO  MASCULINO
# 710         MOTO-AUTO         AUTO             CONDUCTOR     MOTO  MASCULINO
# 712         MOTO-AUTO         AUTO  PASAJERO_ACOMPAÑANTE     MOTO   FEMENINO
# 713         MOTO-AUTO         AUTO  PASAJERO_ACOMPAÑANTE     MOTO   FEMENINO
# 714       MOTO-CARGAS       CARGAS             CONDUCTOR     MOTO  MASCULINO
#
#     EDAD Semestre
# 0     19        1
# 2     30        1
# 3     18        1
# 4     29        1
# 5     30        1
# ..   ...      ...
# 708   41        2
# 710   24        2
# 712   18        2
# 713   43        2
# 714   27        2
#
# [303 rows x 25 columns]

# %%
#agrupo por año y obtengo total de accidentes en motos anuales
df_accidentes_motos = df_motociclistas.groupby('Año')['Víctima'].count().reset_index()
df_accidentes_motos
# Out:
#     Año  Víctima
# 0  2016       65
# 1  2017       56
# 2  2018       57
# 3  2019       50
# 4  2020       29
# 5  2021       46

# %%
#me aseguro de que el tipo de dato de la columna Año sea entero para poder hacer el merge sin problema
df_accidentes_motos['Año'] = df_accidentes_motos['Año'].astype(int)

# %%
#uno esta tabla con la de población total por años
df_kpi2 = pd.merge(df_accidentes_motos, df_poblacion_anios, on='Año', how='left')
df_kpi2
# Out:
#     Año  Víctima  Población Total
# 0  2016       65     3.005929e+06
# 1  2017       56     3.025225e+06
# 2  2018       57     3.044522e+06
# 3  2019       50     3.063818e+06
# 4  2020       29     3.083114e+06
# 5  2021       46     3.102411e+06

# %%
#añado una columna con el número de víctimas del periodo anterior
df_kpi2["Víctimas año anterior"] = df_kpi2["Víctima"].shift(periods=1, fill_value=0)
df_kpi2
# Out:
#     Año  Víctima  Población Total  Víctimas año anterior
# 0  2016       65     3.005929e+06                      0
# 1  2017       56     3.025225e+06                     65
# 2  2018       57     3.044522e+06                     56
# 3  2019       50     3.063818e+06                     57
# 4  2020       29     3.083114e+06                     50
# 5  2021       46     3.102411e+06                     29

# %%
#finalmente calculo el valor que me va a indicar la evolución en el número de accidentes por año
df_kpi2['Evolución']= (df_kpi2['Víctimas año anterior']-df_kpi2['Víctima'])*100/df_kpi2['Víctimas año anterior']
df_kpi2
# Out:
#     Año  Víctima  Población Total  Víctimas año anterior  Evolución
# 0  2016       65     3.005929e+06                      0       -inf
# 1  2017       56     3.025225e+06                     65  13.846154
# 2  2018       57     3.044522e+06                     56  -1.785714
# 3  2019       50     3.063818e+06                     57  12.280702
# 4  2020       29     3.083114e+06                     50  42.000000
# 5  2021       46     3.102411e+06                     29 -58.620690

# %%
#Cambio nombres de las columnas
df_kpi2 = df_kpi2.rename(columns={'Víctima':'Cantidad de víctimas' })

# %%
df_kpi2.to_csv('data_kpi02.csv')
